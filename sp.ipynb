# %%
import heapq
import pprint
import random
from dataclasses import dataclass
from itertools import combinations, product
from typing import List, Optional

import networkx as nx
import numpy as np
import numpy.typing as npt
from icecream import ic

# %%
np.random.seed(1)
random.seed(1)

# %% [markdown]
# ## Initialize the problems

# %%
SIZES = [10, 20, 50, 100, 200, 500, 1000]
DENSITIES = [0.2, 0.5, 0.8, 1.0]
NOISE_LEVELS = [0, 0.1, 0.5, 0.8]
NEGTIVE_VALUES = [False, True]

# %%
def create_problem(
    size: int,
    density: float = 1.0,
    negative_values: bool = False,
    noise_level: float = 0.0,
    seed: int = 42,
) -> npt.NDArray:
    """Problem generator for Lab3"""
    rng = np.random.default_rng(seed)
    map = rng.random(size=(size, 2))
    problem = rng.random((size, size))
    if negative_values:
        problem = problem * 2 - 1
    problem *= noise_level
    for a, b in product(range(size), repeat=2):
        if rng.random() < density:
            problem[a, b] += np.sqrt(
                np.square(map[a, 0] - map[b, 0]) + np.square(map[a, 1] - map[b, 1])
            )
        else:
            problem[a, b] = np.inf
    np.fill_diagonal(problem, 0)
    return (problem * 1_000).round()

# %%
all_combinations = list(product(SIZES, DENSITIES, NOISE_LEVELS, NEGTIVE_VALUES))

# %% [markdown]
# To generated a diverse set of problems, we sample randomly 20 combinations from the se of all possible combinations of the parameters. We save it as a dictionary just so we can print the parameters used to generate each graph.

# %%
problems = [
    {
        "_size": s,
        "_density": d,
        "_noise_level": n,
        "_negative_values": v,
        "grid": create_problem(s, d, v, n),
    }
    for s, d, n, v in random.sample(all_combinations, 20)
]

# %%
pprint.pprint(problems)
# Out:
# [{'_density': 0.2,
#   '_negative_values': False,
#   '_noise_level': 0.1,
#   '_size': 20,
#   'grid': array([[   0.,  355.,   inf,  379.,   inf,   inf,   inf,   inf,  503.,
#           inf,  106.,   inf,   inf,  567.,  737.,  608.,   inf,   inf,
#           inf,   inf],
#        [  inf,    0.,   inf,   inf,   inf,   inf,   inf,   inf,  706.,
#           inf,   inf,   inf,  594.,  785.,   inf,   inf,   inf,   inf,
#           inf,   inf],
#        [  inf,   inf,    0.,   inf,  529.,   inf,   inf,   inf,   inf,
#           inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,
#           inf,   inf],
#        [  inf,   inf,   inf,    0.,   inf,   inf,   inf,   inf,   inf,
#          258.,  477.,   inf,  622.,   inf,   inf,  268.,   inf,   inf,
#          747.,   inf],
#        [  inf,   inf,  535.,   inf,    0.,   inf,   inf,   inf,   inf,
#           inf,   inf,   inf,   inf,   inf,  293.,   inf,   inf,  478.,
#          104.,   inf],
#        [  inf,   inf,   inf,   inf,  582.,    0.,   inf,  755.,   inf,
#           inf,   inf,  690.,  852.,   inf,  337.,   inf,   inf,   inf,
#           inf,   inf],
#        [ 416.,   inf,   inf,   inf,   inf,   inf,    0.,  709.,   inf,
#           inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,
#           inf,   inf],
#        [  inf,   inf,  878.,   inf,   inf,   inf,  666.,    0.,  272.,
#          584.,   inf,   inf,   inf,   inf,  555.,   inf,   inf,   inf,
#           inf,   inf],
#        [  inf,   inf,   inf,   inf,   inf,   inf,   inf,  265.,    0.,
#           inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,
#          684.,  729.],
#        [  inf,   inf,   inf,   inf,   inf,   inf,   inf,  613.,   inf,
#            0.,   inf,   inf,  536.,   inf,  769.,  426.,   inf,   inf,
#           inf,   inf],
#        [  inf,   inf,  932.,   inf,   inf,   inf,  542.,   inf,   inf,
#          328.,    0.,   inf,   inf,   inf,   inf,   inf,   inf,   inf,
#           inf,   inf],
#        [  inf,   inf,  911.,  250.,   inf,   inf,   inf,   inf,   inf,
#           inf,  585.,    0.,   inf,   inf,   inf,   inf,   inf,   inf,
#         1026.,   inf],
#        [ 249.,   inf, 1062.,   inf,   inf,   inf,   inf,   inf,   inf,
#           inf,   inf,   inf,    0.,   inf,   inf,   inf,   inf,   inf,
#           inf,   inf],
#        [  inf,   inf, 1057.,   inf,   inf,   inf,   inf,   inf,   inf,
#           inf,   inf,   inf,   inf,    0.,   inf,  997.,   inf,  214.,
#           inf,   inf],
#        [  inf,   inf,  332.,   inf,  319.,  391.,   inf,  593.,   inf,
#           inf,   inf,  863.,  862.,   inf,    0.,   inf,   inf,   inf,
#           inf,   inf],
#        [ 543.,  389.,   inf,  242.,   inf,   inf,   inf,   inf,   inf,
#           inf,   inf,   inf,   inf,   inf,   inf,    0.,   inf,   inf,
#          837.,   inf],
#        [  inf,  637.,  660.,  611.,   inf,  600.,  630.,  252.,  416.,
#           inf,   inf,   inf,   inf,   inf,  372.,   inf,    0.,  275.,
#           inf,   inf],
#        [  inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,
#           inf,   inf,   inf,   inf,  214.,  587.,   inf,  314.,    0.,
#           inf,   inf],
#        [  inf,   inf,   inf,   inf,  125.,  599.,   inf,  484.,   inf,
#           inf,  706., 1004.,   inf,   inf,  212.,   inf,   inf,   inf,
#            0.,   inf],
#        [ 659.,   inf,   inf,   inf,   inf,  375.,   inf,   inf,   inf,
#           inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,   inf,
#           inf,    0.]])},
#  {'_density': 0.8,
#   '_negative_values': True,
#   '_noise_level': 0,
#   '_size': 200,
#   'grid': array([[  0., 272., 866., ...,  inf, 152.,  inf],
#        [272.,   0., 813., ..., 881., 403., 474.],
#        [866., 813.,   0., ..., 528.,  inf, 646.],
#        ...,
#        [ inf, 881., 528., ...,   0.,  inf, 446.],
#        [152., 403., 999., ..., 828.,   0.,  inf],
#        [315., 474., 646., ..., 446., 395.,   0.]], shape=(200, 200))},
#  {'_density': 1.0,
#   '_negative_values': False,
#   '_noise_level': 0,
#   '_size': 1000,
#   'grid': array([[  0., 272., 866., ..., 434., 500., 108.],
#        [272.,   0., 813., ..., 387., 678., 178.],
#        [866., 813.,   0., ..., 441., 668., 879.],
#        ...,
#        [434., 387., 441., ...,   0., 460., 438.],
#        [500., 678., 668., ..., 460.,   0., 590.],
#        [108., 178., 879., ..., 438., 590.,   0.]], shape=(1000, 1000))},
#  {'_density': 0.5,
#   '_negative_values': True,
#   '_noise_level': 0.5,
#   '_size': 1000,
#   'grid': array([[   0.,   inf,   inf, ...,  144.,  979., -294.],
#        [ 601.,    0.,  558., ...,  341.,   inf,   inf],
#        [1082.,  671.,    0., ...,  412.,  522.,  994.],
#        ...,
#        [  inf,   inf,   inf, ...,    0.,  947.,  605.],
#        [  inf,   inf,   inf, ...,   inf,    0.,   inf],
#        [  inf,   inf,   inf, ...,  760.,   inf,    0.]],
#       shape=(1000, 1000))},
#  {'_density': 0.2,
#   '_negative_values': True,
#   '_noise_level': 0.1,
#   '_size': 1000,
#   'grid': array([[  0.,  inf,  inf, ...,  inf, 596.,  28.],
#        [ inf,   0.,  inf, ...,  inf,  inf,  inf],
#        [ inf, 785.,   0., ...,  inf, 639., 902.],
#        ...,
#        [ inf,  inf,  inf, ...,   0., 557.,  inf],
#        [ inf,  inf,  inf, ...,  inf,   0.,  inf],
#        [ inf,  inf,  inf, ...,  inf,  inf,   0.]], shape=(1000, 1000))},
#  {'_density': 0.8,
#   '_negative_values': False,
#   '_noise_level': 0,
#   '_size': 10,
#   'grid': array([[   0.,  272.,  866.,  347.,  646.,  633.,  405.,  392.,  435.,
#          200.],
#        [ 272.,    0.,  813.,  132.,  771.,  539.,   inf,  627.,  703.,
#           73.],
#        [ 866.,  813.,    0.,  693.,  526.,  281.,  571.,  826., 1021.,
#          810.],
#        [  inf,   inf,  693.,    0.,  717.,  415.,  123.,  643.,  751.,
#          168.],
#        [ 646.,   inf,  526.,  717.,    0.,  535.,   inf,   inf,  576.,
#           inf],
#        [ 633.,  539.,  281.,   inf,  535.,    0.,  292.,   inf,   inf,
#          544.],
#        [  inf,   inf,  571.,  123.,  636.,  292.,    0.,  628.,  764.,
#          265.],
#        [  inf,  627.,  826.,   inf,  386.,  703.,  628.,    0.,  198.,
#          558.],
#        [ 435.,   inf, 1021.,  751.,  576.,  882.,  764.,  198.,    0.,
#          630.],
#        [ 200.,   73.,  810.,   inf,  723.,  544.,  265.,  558.,   inf,
#            0.]])},
#  {'_density': 0.2,
#   '_negative_values': True,
#   '_noise_level': 0,
#   '_size': 50,
#   'grid': array([[  0.,  inf,  inf, ...,  inf,  inf,  inf],
#        [ inf,   0.,  inf, ..., 561.,  inf,  inf],
#        [ inf,  inf,   0., ..., 403.,  inf,  27.],
#        ...,
#        [ inf,  inf,  inf, ...,   0.,  inf,  inf],
#        [ inf,  inf,  inf, ...,  inf,   0.,  inf],
#        [ inf,  inf,  inf, ...,  inf,  inf,   0.]], shape=(50, 50))},
#  {'_density': 1.0,
#   '_negative_values': False,
#   '_noise_level': 0.8,
#   '_size': 10,
#   'grid': array([[   0.,  556., 1643., 1062., 1269.,  789.,  779.,  428.,  558.,
#          747.],
#        [ 868.,    0., 1074.,  428., 1147.,  691.,  353., 1008.,  884.,
#          608.],
#        [1216., 1480.,    0.,  943., 1192.,  925.,  881., 1057., 1567.,
#          922.],
#        [ 507.,  138., 1323.,    0., 1281., 1040.,  490., 1098.,  863.,
#          260.],
#        [1181., 1148.,  979., 1329.,    0.,  977., 1083.,  629.,  600.,
#         1072.],
#        [ 805.,  866.,  964.,  602.,  581.,    0.,  527., 1233., 1328.,
#         1171.],
#        [ 937.,  574., 1222.,  256.,  654.,  364.,    0.,  998.,  893.,
#          666.],
#        [ 514., 1184., 1183.,  948.,  627., 1208.,  918.,    0.,  292.,
#         1327.],
#        [1161., 1262., 1234., 1527., 1199., 1456., 1124.,  415.,    0.,
#         1352.],
#        [ 565.,  235., 1055.,  631.,  864., 1229.,  872., 1133.,  976.,
#            0.]])},
#  {'_density': 1.0,
#   '_negative_values': False,
#   '_noise_level': 0.8,
#   '_size': 100,
#   'grid': array([[   0., 1049., 1267., ..., 1314., 1093., 1106.],
#        [ 895.,    0., 1242., ..., 1111.,  681., 1121.],
#        [1108., 1548.,    0., ..., 1299.,  804., 1083.],
#        ...,
#        [ 853., 1037., 1369., ...,    0., 1125.,  523.],
#        [1046.,  883.,  677., ..., 1602.,    0.,  879.],
#        [1372., 1384., 1422., ...,  684., 1196.,    0.]], shape=(100, 100))},
#  {'_density': 0.2,
#   '_negative_values': False,
#   '_noise_level': 0.1,
#   '_size': 1000,
#   'grid': array([[  0.,  inf,  inf, ...,  inf, 598., 118.],
#        [ inf,   0.,  inf, ...,  inf,  inf,  inf],
#        [ inf, 849.,   0., ...,  inf, 704., 940.],
#        ...,
#        [ inf,  inf,  inf, ...,   0., 559.,  inf],
#        [ inf,  inf,  inf, ...,  inf,   0.,  inf],
#        [ inf,  inf,  inf, ...,  inf,  inf,   0.]], shape=(1000, 1000))},
#  {'_density': 0.8,
#   '_negative_values': True,
#   '_noise_level': 0.1,
#   '_size': 100,
#   'grid': array([[  0., 366., 866., ..., 733., 525.,  inf],
#        [328.,   0., 821., ..., 834.,  inf,  inf],
#        [ inf, 897.,   0., ..., 824., 487., 676.],
#        ...,
#        [618., 816.,  inf, ...,   0., 801., 134.],
#        [514.,  inf, 456., ..., 920.,   0., 640.],
#        [687.,  inf, 760., ..., 174., 719.,   0.]], shape=(100, 100))},
#  {'_density': 1.0,
#   '_negative_values': False,
#   '_noise_level': 0,
#   '_size': 100,
#   'grid': array([[  0., 272., 866., ..., 673., 469., 592.],
#        [272.,   0., 813., ..., 875., 314., 767.],
#        [866., 813.,   0., ..., 799., 515., 673.],
#        ...,
#        [673., 875., 799., ...,   0., 826., 138.],
#        [469., 314., 515., ..., 826.,   0., 693.],
#        [592., 767., 673., ..., 138., 693.,   0.]], shape=(100, 100))},
#  {'_density': 0.2,
#   '_negative_values': False,
#   '_noise_level': 0.8,
#   '_size': 500,
#   'grid': array([[   0.,   inf,  969., ...,   inf,   inf,   inf],
#        [  inf,    0.,   inf, ...,   inf,   inf,   inf],
#        [  inf,   inf,    0., ...,   inf,   inf,   inf],
#        ...,
#        [ 359.,   inf, 1140., ...,    0.,   inf,  408.],
#        [  inf, 1506.,   inf, ...,   inf,    0.,   inf],
#        [  inf,   inf, 1396., ...,   inf,   inf,    0.]], shape=(500, 500))},
#  {'_density': 0.2,
#   '_negative_values': True,
#   '_noise_level': 0,
#   '_size': 100,
#   'grid': array([[  0.,  inf,  inf, ...,  inf,  inf,  inf],
#        [ inf,   0.,  inf, ...,  inf,  inf,  inf],
#        [ inf, 813.,   0., ...,  inf,  inf,  inf],
#        ...,
#        [ inf,  inf,  inf, ...,   0.,  inf, 138.],
#        [ inf,  inf, 515., ...,  inf,   0.,  inf],
#        [592.,  inf,  inf, ..., 138.,  inf,   0.]], shape=(100, 100))},
#  {'_density': 0.5,
#   '_negative_values': True,
#   '_noise_level': 0,
#   '_size': 1000,
#   'grid': array([[  0.,  inf,  inf, ..., 434., 500., 108.],
#        [272.,   0., 813., ..., 387.,  inf,  inf],
#        [866., 813.,   0., ..., 441., 668., 879.],
#        ...,
#        [ inf,  inf,  inf, ...,   0., 460., 438.],
#        [ inf,  inf,  inf, ...,  inf,   0.,  inf],
#        [ inf,  inf,  inf, ..., 438.,  inf,   0.]], shape=(1000, 1000))},
#  {'_density': 0.8,
#   '_negative_values': True,
#   '_noise_level': 0.5,
#   '_size': 20,
#   'grid': array([[ 0.000e+00,  6.050e+02,  1.066e+03,  1.600e+02,  9.780e+02,
#          9.380e+02,        inf,  1.810e+02,  6.170e+02, -1.600e+02,
#         -2.140e+02,        inf,  5.310e+02,  6.650e+02,  8.710e+02,
#          8.100e+02,        inf,  4.620e+02,  2.850e+02,  2.080e+02],
#        [ 4.400e+02,  0.000e+00,        inf,  3.970e+02,  9.060e+02,
#          5.930e+02,  3.080e+02,        inf,  2.340e+02,  9.000e+00,
#          7.200e+01,  1.340e+02,  8.620e+02,  4.960e+02,  2.630e+02,
#          7.500e+01,  4.190e+02,  8.020e+02,  8.190e+02,  9.160e+02],
#        [ 1.030e+03,  7.200e+02,  0.000e+00,  3.600e+02,  4.900e+01,
#         -1.290e+02,  7.930e+02,  7.880e+02,  6.830e+02,  8.110e+02,
#          5.610e+02,  1.077e+03,  9.840e+02,  8.850e+02,  1.000e+02,
#          7.810e+02,  5.100e+02,  4.590e+02,  1.190e+02,  7.950e+02],
#        [ 7.560e+02,        inf,        inf,  0.000e+00,  9.950e+02,
#          6.320e+02,  7.200e+01,        inf,  3.480e+02,  5.710e+02,
#          3.870e+02,        inf,  3.980e+02,  8.780e+02,  2.920e+02,
#          5.390e+02,  8.600e+02,  8.830e+02,  6.350e+02,        inf],
#        [       inf,  9.210e+02,  1.110e+02,  6.320e+02,  0.000e+00,
#          5.290e+02,        inf,        inf,  1.790e+02,  8.100e+02,
#          3.080e+02,  1.377e+03,  7.800e+02,  3.760e+02,  3.250e+02,
#          3.280e+02,  6.720e+02,  4.120e+02,  3.080e+02,        inf],
#        [       inf,  5.300e+02,        inf,        inf,  5.080e+02,
#          0.000e+00,  1.240e+02,  7.240e+02,  8.210e+02,  6.500e+01,
#          1.017e+03,  9.970e+02,  4.780e+02,        inf, -6.500e+01,
#          5.480e+02,  3.390e+02,  9.030e+02,  7.380e+02,  5.630e+02],
#        [ 1.300e+01,  6.650e+02,        inf, -3.400e+02,  6.910e+02,
#          1.630e+02,  0.000e+00,  9.370e+02,  5.810e+02,  7.180e+02,
#          2.730e+02,        inf,  3.980e+02,  1.235e+03,        inf,
#         -2.790e+02,        inf,  1.149e+03,        inf,  6.930e+02],
#        [ 7.830e+02,  1.021e+03,  8.450e+02,  4.590e+02,        inf,
#          8.650e+02,  5.020e+02,  0.000e+00,  4.440e+02,  3.200e+02,
#                inf,  5.900e+02, -4.100e+01,  5.160e+02,  1.930e+02,
#          4.790e+02,  2.850e+02,  4.200e+02,        inf,  3.030e+02],
#        [ 7.120e+02,  1.175e+03,        inf,  3.950e+02,        inf,
#          6.120e+02,        inf,  3.750e+02,  0.000e+00,  6.360e+02,
#          5.490e+02,  1.009e+03,        inf,        inf,  9.530e+02,
#          1.162e+03,  1.400e+01, -2.250e+02,  1.019e+03,  5.860e+02],
#        [ 1.000e+00,  6.100e+01,        inf,  6.240e+02,        inf,
#          9.690e+02, -2.100e+02,  6.130e+02,  7.640e+02,  0.000e+00,
#                inf,        inf,  9.060e+02,  7.860e+02,  1.108e+03,
#          6.500e+02,  5.330e+02,  8.540e+02,  2.330e+02,        inf],
#        [ 4.150e+02,        inf,  6.420e+02,  4.620e+02,  7.430e+02,
#                inf,  5.850e+02,  2.520e+02,  2.290e+02,  2.120e+02,
#          0.000e+00,        inf,  1.150e+02,  1.740e+02,        inf,
#          8.590e+02,        inf, -6.200e+01,  2.060e+02,  7.120e+02],
#        [ 1.410e+02,        inf,  6.910e+02, -1.210e+02,  1.373e+03,
#          2.660e+02,        inf,        inf,  5.430e+02, -1.810e+02,
#          1.340e+02,  0.000e+00,        inf,  1.079e+03,  1.024e+03,
#          1.310e+02,        inf,  8.680e+02,  1.314e+03,  1.128e+03],
#        [-2.120e+02,  1.910e+02,  7.750e+02,  3.410e+02,  7.700e+02,
#          7.540e+02,  1.920e+02,        inf,  2.830e+02,  4.100e+01,
#          4.950e+02,        inf,  0.000e+00, -5.500e+01,        inf,
#          1.176e+03,  9.650e+02,  6.110e+02,  9.860e+02,  8.700e+02],
#        [ 7.790e+02,  3.970e+02,  1.040e+03,        inf,  8.870e+02,
#          8.510e+02,  6.840e+02,  3.240e+02, -1.430e+02,  3.300e+02,
#                inf,  9.040e+02,        inf,  0.000e+00,  5.780e+02,
#          7.920e+02,  2.350e+02,  3.310e+02,  3.450e+02,        inf],
#        [ 1.082e+03,  6.850e+02,  1.270e+02,        inf,  5.830e+02,
#          4.790e+02,  8.140e+02,  5.720e+02,  8.700e+02,  4.630e+02,
#          9.220e+02,  5.450e+02,  9.870e+02,  1.072e+03,  0.000e+00,
#          7.700e+02, -4.800e+01,  8.110e+02, -2.070e+02,  5.100e+02],
#        [ 1.670e+02,  7.520e+02,        inf,  2.760e+02,  1.087e+03,
#          6.710e+02,  6.220e+02,  5.530e+02,  1.014e+03,        inf,
#          7.290e+02, -9.100e+01,  8.390e+02,  1.037e+03,  6.210e+02,
#          0.000e+00,  9.930e+02,        inf,  7.790e+02,  6.970e+02],
#        [ 8.850e+02,  2.450e+02,  2.650e+02,  1.900e+02,        inf,
#          4.770e+02,  8.270e+02,  3.570e+02,  2.160e+02,  9.640e+02,
#          6.950e+02,  6.010e+02,  3.500e+02,        inf,  1.400e+01,
#                inf,  0.000e+00,  1.690e+02,  1.060e+02,        inf],
#        [ 4.470e+02,        inf,  1.151e+03,  6.430e+02,        inf,
#          1.231e+03,        inf,  4.970e+02, -2.300e+02,  9.200e+02,
#          4.690e+02,  4.860e+02,  3.970e+02,  3.320e+02,  9.800e+01,
#          7.800e+02,  5.570e+02,  0.000e+00,  4.030e+02,  4.800e+02],
#        [ 4.470e+02,  1.180e+03,        inf,  3.140e+02,  5.220e+02,
#          8.910e+02,  4.040e+02,  7.370e+02,  1.980e+02,        inf,
#          8.050e+02,  1.089e+03,        inf,  9.450e+02, -2.620e+02,
#                inf,        inf,  7.210e+02,  0.000e+00,  6.280e+02],
#        [ 7.500e+02,  1.680e+02, -1.610e+02,  9.800e+01,        inf,
#          5.960e+02,  1.830e+02,  8.420e+02,        inf,  9.030e+02,
#          1.045e+03,  1.049e+03,  9.260e+02,  1.008e+03, -3.860e+02,
#          2.990e+02, -6.000e+01,        inf,  4.620e+02,  0.000e+00]])},
#  {'_density': 1.0,
#   '_negative_values': False,
#   '_noise_level': 0,
#   '_size': 10,
#   'grid': array([[   0.,  272.,  866.,  347.,  646.,  633.,  405.,  392.,  435.,
#          200.],
#        [ 272.,    0.,  813.,  132.,  771.,  539.,  249.,  627.,  703.,
#           73.],
#        [ 866.,  813.,    0.,  693.,  526.,  281.,  571.,  826., 1021.,
#          810.],
#        [ 347.,  132.,  693.,    0.,  717.,  415.,  123.,  643.,  751.,
#          168.],
#        [ 646.,  771.,  526.,  717.,    0.,  535.,  636.,  386.,  576.,
#          723.],
#        [ 633.,  539.,  281.,  415.,  535.,    0.,  292.,  703.,  882.,
#          544.],
#        [ 405.,  249.,  571.,  123.,  636.,  292.,    0.,  628.,  764.,
#          265.],
#        [ 392.,  627.,  826.,  643.,  386.,  703.,  628.,    0.,  198.,
#          558.],
#        [ 435.,  703., 1021.,  751.,  576.,  882.,  764.,  198.,    0.,
#          630.],
#        [ 200.,   73.,  810.,  168.,  723.,  544.,  265.,  558.,  630.,
#            0.]])},
#  {'_density': 1.0,
#   '_negative_values': False,
#   '_noise_level': 0.5,
#   '_size': 100,
#   'grid': array([[   0.,  758., 1117., ..., 1074.,  859.,  913.],
#        [ 661.,    0., 1082., ..., 1023.,  543.,  988.],
#        [1017., 1273.,    0., ..., 1112.,  696.,  929.],
#        ...,
#        [ 786.,  976., 1155., ...,    0., 1013.,  378.],
#        [ 830.,  670.,  617., ..., 1311.,    0.,  810.],
#        [1079., 1152., 1141., ...,  479., 1008.,    0.]], shape=(100, 100))},
#  {'_density': 0.2,
#   '_negative_values': True,
#   '_noise_level': 0.8,
#   '_size': 10,
#   'grid': array([[   0.,   inf, 1619.,   inf, 1091.,   inf,   inf, -337., -119.,
#           inf],
#        [ 664.,    0.,   inf,   inf,   inf,   42.,   inf,   inf,   inf,
#          344.],
#        [  inf,   inf,    0.,   inf,   inf,   inf,   inf,   inf,   inf,
#          234.],
#        [  inf,   inf, 1152.,    0., 1045.,   inf,   inf,   inf,   inf,
#           inf],
#        [ 915.,   inf,   inf, 1141.,    0.,   inf,   inf,   inf,   inf,
#           inf],
#        [  inf,   inf,   inf,   inf, -172.,    0.,   inf,   inf,   inf,
#           inf],
#        [  inf,   inf,   inf,   inf,   inf,   inf,    0.,  567.,   inf,
#           inf],
#        [  inf,   inf,  740.,   inf,   69.,  912.,   inf,    0., -414.,
#           inf],
#        [  inf,   inf,   inf, 1502., 1022.,   inf,  683.,   inf,    0.,
#           inf],
#        [  inf,   inf,  500.,   inf,   inf,   inf,  679.,  909.,   inf,
#            0.]])},
#  {'_density': 0.8,
#   '_negative_values': True,
#   '_noise_level': 0.5,
#   '_size': 1000,
#   'grid': array([[   0.,  218.,   inf, ...,  144.,  979., -294.],
#        [ 601.,    0.,  558., ...,  341.,  518.,   inf],
#        [1082.,  671.,    0., ...,  412.,  522.,  994.],
#        ...,
#        [  inf,  659.,  789., ...,    0.,  947.,  605.],
#        [  inf,   inf,  184., ...,   inf,    0., 1061.],
#        [-281.,   inf,   inf, ...,  760.,   inf,    0.]],
#       shape=(1000, 1000))}]

# %%
masked = [np.ma.masked_array(p["grid"], mask=np.isinf(p["grid"])) for p in problems]
Gs = [nx.from_numpy_array(m, create_using=nx.DiGraph) for m in masked]

# %% [markdown]
# ## Using the A-star algorithm to find the shortest path
#
# We implement the A-star algorithm in a classical way but we use a heuristic based on the Bellman-Ford algorithm to handle graphs with negative edge weights.

# %%
@dataclass
class Node:
    """
    Represents a node in the A* search algorithm.

    Attributes:
        id (int): The identifier of the node.
        g (float): The cost from the start node to this node.
        h (float): The heuristic estimate from this node to the target node.
        f (float): The total estimated cost (g + h).
        parent (Optional[Node]): The parent node in the path.
    """

    id: int
    g: float
    h: float
    parent: Optional["Node"] = None

    def __post_init__(self):
        self.f = self.g + self.h

    def __lt__(self, other: "Node"):
        return self.f < other.f


def heuristic(G: nx.DiGraph, node: int, target: int) -> float:
    """
    Computes an heuristic for the A* algorithm

    Uses networkx's implementation of the Bellman-Ford algorithm to compute the
    shortest-path distances to the target node from all other nodes by
    running the algorithm on a reverse view of the graph. This heuristic should
    handle negative edge weights and detect negative cycles. When a negative
    cycle is detected, the returned heuristic is zero, which is admissible.

    Args:
        G (nx.DiGraph): the graph. The object should be assumed mutable. A cache
            of the Bellman-Ford results is stored in
            `G.graph["_bf_to_target_cache"]` for each target node to avoid
            recomputing the same distances multiple times.
        node (int): the starting node
        target (int): the target node

    Returns:
        float: the heuristic estimate of the distance from `node` to `target`
    """

    cache = G.graph.setdefault("_bf_to_target_cache", {})
    if target not in cache:
        try:
            dist = nx.single_source_bellman_ford_path_length(
                G.reverse(copy=False), target
            )
        except nx.NetworkXUnbounded:
            cache[target] = {}
        else:
            cache[target] = dist

    return float(cache[target].get(node, 0.0))


def astar(
    G: nx.DiGraph, source: int, target: int
) -> tuple[Optional[List[int]], float] | None:
    """
    Implements the A* search algorithm.

    Args:
        G (nx.DiGraph): The directed graph on which to perform the search.
        source (int): The starting node identifier.
        target (int): The target node identifier.

    Returns:
        (tuple[Optional[List[int]], float] | None): A tuple containing the list
            of node identifiers representing the shortest path from source to
            target and the total cost of that path. If no path exists, returns
            None.
    """

    start = Node(id=source, g=0, h=0)
    open_set = []
    closed_set = set()
    heapq.heappush(open_set, start)

    while open_set:
        current = heapq.heappop(open_set)

        if current.id == target:
            path = []
            cost = current.g
            while current:
                path.append(current.id)
                current = current.parent
            return path[::-1], cost

        closed_set.add(current.id)

        for neighbor in G.neighbors(current.id):
            if neighbor in closed_set:
                continue

            g_cost = current.g + G[current.id][neighbor]["weight"]
            h_cost = heuristic(G, neighbor, target)

            neighbor_node = Node(id=neighbor, g=g_cost, h=h_cost, parent=current)

            if any(
                open_node.id == neighbor and open_node.g <= g_cost
                for open_node in open_set
            ):
                continue

            heapq.heappush(open_set, neighbor_node)

# %% [markdown]
# Here we compare the results from networkx's built-in Dijkstra's algorithm and our implementation of the A-star. With Dijkstra, if we find negative weights, a `ValueError` exception is raised so in that case we skip the comparison. We randomly sample 20 source-destination pairs from each problem. In the assertions, we use a "greater or equal" comparison because A-star might find a shorter path by traversing negative edges.

# %%
for p, G in zip(problems, Gs):
    for s, d in random.sample(list(combinations(range(p["grid"].shape[0]), 2)), 20):
        try:
            path_dijkstra = nx.shortest_path(G, s, d, weight="weight")
            cost_dijkstra = nx.path_weight(G, path_dijkstra, weight="weight")

            path_astar, cost_astar = astar(G, s, d)  # type: ignore
        except nx.NetworkXNoPath:
            path_dijkstra = None
            cost_dijkstra = np.inf
        except ValueError:
            # negative weights with Dijkstra are not admissible in networkx, but
            # we can still work with it using A*
            path_dijkstra = None
            cost_dijkstra = np.inf

        ic(s, d, path_dijkstra, cost_dijkstra, path_astar, cost_astar)
        assert cost_dijkstra >= cost_astar or cost_dijkstra == np.inf
# Out:
# ic| s: 6
#     d: 7
#     path_dijkstra: [6, 7]
#     cost_dijkstra: 709.0
#     path_astar: [6, 7]
#     cost_astar: 709.0
# ic| s: 6
#     d: 18
#     path_dijkstra: [6, 0, 3, 18]
#     cost_dijkstra: 1542.0
#     path_astar: [6, 0, 3, 18]
#     cost_astar: 1542.0
# ic| s: 11
#     d: 13
#     path_dijkstra: [11, 3, 15, 0, 13]
#     cost_dijkstra: 1628.0
#     path_astar: [11, 3, 15, 0, 13]
#     cost_astar: 1628.0
# ic| s: 0
#     d: 1
#     path_dijkstra: [0, 1]
#     cost_dijkstra: 355.0
#     path_astar: [0, 1]
#     cost_astar: 355.0
# ic| s: 14
#     d: 18
#     path_dijkstra: [14, 4, 18]
#     cost_dijkstra: 423.0
#     path_astar: [14, 4, 18]
#     cost_astar: 423.0
# ic| s: 7
#     d: 10
#     path_dijkstra: [7, 6, 0, 10]
#     cost_dijkstra: 1188.0
#     path_astar: [7, 6, 0, 10]
#     cost_astar: 1188.0
# ic| s: 3
#     d: 18
#     path_dijkstra: [3, 18]
#     cost_dijkstra: 747.0
#     path_astar: [3, 18]
#     cost_astar: 747.0
# ic| s: 16
#     d: 17
#     path_dijkstra: [16, 17]
#     cost_dijkstra: 275.0
#     path_astar: [16, 17]
#     cost_astar: 275.0
# ic| s: 3
#     d: 8
#     path_dijkstra: [3, 9, 7, 8]
#     cost_dijkstra: 1143.0
#     path_astar: [3, 9, 7, 8]
#     cost_astar: 1143.0
# ic| s: 10
#     d: 17
#     path_dijkstra: [10, 6, 0, 13, 17]
#     cost_dijkstra: 1739.0
#     path_astar: [10, 6, 0, 13, 17]
#     cost_astar: 1739.0
# ic| s: 1
#     d: 9
#     path_dijkstra: [1, 12, 0, 10, 9]
#     cost_dijkstra: 1277.0
#     path_astar: [1, 12, 0, 10, 9]
#     cost_astar: 1277.0
# ic| s: 4
#     d: 16
#     path_dijkstra: [4, 17, 16]
#     cost_dijkstra: 792.0
#     path_astar: [4, 17, 16]
#     cost_astar: 792.0
# ic| s: 0
#     d: 8
#     path_dijkstra: [0, 8]
#     cost_dijkstra: 503.0
#     path_astar: [0, 8]
#     cost_astar: 503.0
# ic| s: 0
#     d: 6
#     path_dijkstra: [0, 10, 6]
#     cost_dijkstra: 648.0
#     path_astar: [0, 10, 6]
#     cost_astar: 648.0
# ic| s: 0
#     d: 7
#     path_dijkstra: [0, 8, 7]
#     cost_dijkstra: 768.0
#     path_astar: [0, 8, 7]
#     cost_astar: 768.0
# ic| s: 12
#     d: 17
#     path_dijkstra: [12, 0, 13, 17]
#     cost_dijkstra: 1030.0
#     path_astar: [12, 0, 13, 17]
#     cost_astar: 1030.0
# ic| s: 9
#     d: 13
#     path_dijkstra: [9, 12, 0, 13]
#     cost_dijkstra: 1352.0
#     path_astar: [9, 12, 0, 13]
#     cost_astar: 1352.0
# ic| s: 0
#     d: 3
#     path_dijkstra: [0, 3]
#     cost_dijkstra: 379.0
#     path_astar: [0, 3]
#     cost_astar: 379.0
# ic| s: 5
#     d: 18
#     path_dijkstra: [5, 4, 18]
#     cost_dijkstra: 686.0
#     path_astar: [5, 4, 18]
#     cost_astar: 686.0
# ic| s: 14
#     d: 15
#     path_dijkstra: [14, 11, 3, 15]
#     cost_dijkstra: 1381.0
#     path_astar: [14, 11, 3, 15]
#     cost_astar: 1381.0
# ic| s: 39
#     d: 117
#     path_dijkstra: [39, 178, 117]
#     cost_dijkstra: 376.0
#     path_astar: [39, 178, 117]
#     cost_astar: 376.0
# ic| s: 89
#     d: 126
#     path_dijkstra: [89, 126]
#     cost_dijkstra: 665.0
#     path_astar: [89, 126]
#     cost_astar: 665.0
# ic| s: 4
#     d: 166
#     path_dijkstra: [4, 166]
#     cost_dijkstra: 700.0
#     path_astar: [4, 166]
#     cost_astar: 700.0
# ic| s: 127
#     d: 145
#     path_dijkstra: [127, 145]
#     cost_dijkstra: 915.0
#     path_astar: [127, 145]
#     cost_astar: 915.0
# ic| s: 40
#     d: 125
#     path_dijkstra: [40, 125]
#     cost_dijkstra: 461.0
#     path_astar: [40, 125]
#     cost_astar: 461.0
# ic| s: 94
#     d: 108
#     path_dijkstra: [94, 108]
#     cost_dijkstra: 631.0
#     path_astar: [94, 108]
#     cost_astar: 631.0
# ic| s: 114
#     d: 116
#     path_dijkstra: [114, 116]
#     cost_dijkstra: 592.0
#     path_astar: [114, 116]
#     cost_astar: 592.0
# ic| s: 139
#     d: 186
#     path_dijkstra: [139, 186]
#     cost_dijkstra: 741.0
#     path_astar: [139, 186]
#     cost_astar: 741.0
# ic| s: 42
#     d: 183
#     path_dijkstra: [42, 199, 183]
#     cost_dijkstra: 950.0
#     path_astar: [42, 199, 183]
#     cost_astar: 950.0
# ic| s: 68
#     d: 142
#     path_dijkstra: [68, 142]
#     cost_dijkstra: 393.0
#     path_astar: [68, 142]
#     cost_astar: 393.0
# ic| s: 42
#     d: 111
#     path_dijkstra: [42, 59, 111]
#     cost_dijkstra: 1076.0
#     path_astar: [42, 59, 111]
#     cost_astar: 1076.0
# ic| s: 39
#     d: 189
#     path_dijkstra: [39, 189]
#     cost_dijkstra: 182.0
#     path_astar: [39, 189]
#     cost_astar: 182.0
# ic| s: 101
#     d: 113
#     path_dijkstra: [101, 113]
#     cost_dijkstra: 629.0
#     path_astar: [101, 113]
#     cost_astar: 629.0
# ic| s: 55
#     d: 91
#     path_dijkstra: [55, 91]
#     cost_dijkstra: 130.0
#     path_astar: [55, 91]
#     cost_astar: 130.0
# ic| s: 94
#     d: 108
#     path_dijkstra: [94, 108]
#     cost_dijkstra: 631.0
#     path_astar: [94, 108]
#     cost_astar: 631.0
# ic| s: 114
#     d: 116
#     path_dijkstra: [114, 116]
#     cost_dijkstra: 592.0
#     path_astar: [114, 116]
#     cost_astar: 592.0
# ic| s: 139
#     d: 186
#     path_dijkstra: [139, 186]
#     cost_dijkstra: 741.0
#     path_astar: [139, 186]
#     cost_astar: 741.0
# ic| s: 42
#     d: 183
#     path_dijkstra: [42, 199, 183]
#     cost_dijkstra: 950.0
#     path_astar: [42, 199, 183]
#     cost_astar: 950.0
# ic| s: 68
#     d: 142
#     path_dijkstra: [68, 142]
#     cost_dijkstra: 393.0
#     path_astar: [68, 142]
#     cost_astar: 393.0
# ic| s: 42
#     d: 111
#     path_dijkstra: [42, 59, 111]
#     cost_dijkstra: 1076.0
#     path_astar: [42, 59, 111]
#     cost_astar: 1076.0
# ic| s: 39
#     d: 189
#     path_dijkstra: [39, 189]
#     cost_dijkstra: 182.0
#     path_astar: [39, 189]
#     cost_astar: 182.0
# ic| s: 101
#     d: 113
#     path_dijkstra: [101, 113]
#     cost_dijkstra: 629.0
#     path_astar: [101, 113]
#     cost_astar: 629.0
# ic| s: 55
#     d: 91
#     path_dijkstra: [55, 91]
#     cost_dijkstra: 130.0
#     path_astar: [55, 91]
#     cost_astar: 130.0
# ic| s: 3
#     d: 114
#     path_dijkstra: [3, 114]
#     cost_dijkstra: 692.0
#     path_astar: [3, 114]
#     cost_astar: 692.0
# ic| s: 87
#     d: 153
#     path_dijkstra: [87, 153]
#     cost_dijkstra: 634.0
#     path_astar: [87, 153]
#     cost_astar: 634.0
# ic| s: 141
#     d: 186
#     path_dijkstra: [141, 157, 186]
#     cost_dijkstra: 164.0
#     path_astar: [141, 157, 186]
#     cost_astar: 164.0
# ic| s: 17
#     d: 47
#     path_dijkstra: [17, 47]
#     cost_dijkstra: 472.0
#     path_astar: [17, 47]
#     cost_astar: 472.0
# ic| s: 33
#     d: 86
#     path_dijkstra: [33, 86]
#     cost_dijkstra: 701.0
#     path_astar: [33, 86]
#     cost_astar: 701.0
# ic| s: 56
#     d: 165
#     path_dijkstra: [56, 165]
#     cost_dijkstra: 571.0
#     path_astar: [56, 165]
#     cost_astar: 571.0
# ic| s: 3
#     d: 114
#     path_dijkstra: [3, 114]
#     cost_dijkstra: 692.0
#     path_astar: [3, 114]
#     cost_astar: 692.0
# ic| s: 87
#     d: 153
#     path_dijkstra: [87, 153]
#     cost_dijkstra: 634.0
#     path_astar: [87, 153]
#     cost_astar: 634.0
# ic| s: 141
#     d: 186
#     path_dijkstra: [141, 157, 186]
#     cost_dijkstra: 164.0
#     path_astar: [141, 157, 186]
#     cost_astar: 164.0
# ic| s: 17
#     d: 47
#     path_dijkstra: [17, 47]
#     cost_dijkstra: 472.0
#     path_astar: [17, 47]
#     cost_astar: 472.0
# ic| s: 33
#     d: 86
#     path_dijkstra: [33, 86]
#     cost_dijkstra: 701.0
#     path_astar: [33, 86]
#     cost_astar: 701.0
# ic| s: 56
#     d: 165
#     path_dijkstra: [56, 165]
#     cost_dijkstra: 571.0
#     path_astar: [56, 165]
#     cost_astar: 571.0
# ic| s: 65
#     d: 592
#     path_dijkstra: [65, 592]
#     cost_dijkstra: 102.0
#     path_astar: [65, 592]
#     cost_astar: 102.0
# ic| s: 65
#     d: 592
#     path_dijkstra: [65, 592]
#     cost_dijkstra: 102.0
#     path_astar: [65, 592]
#     cost_astar: 102.0
# ic| s: 530
#     d: 868
#     path_dijkstra: [530, 757, 868]
#     cost_dijkstra: 399.0
#     path_astar: [530, 778, 868]
#     cost_astar: 399.0
# ic| s: 530
#     d: 868
#     path_dijkstra: [530, 757, 868]
#     cost_dijkstra: 399.0
#     path_astar: [530, 778, 868]
#     cost_astar: 399.0
# ic| s: 193
#     d: 343
#     path_dijkstra: [193, 343]
#     cost_dijkstra: 297.0
#     path_astar: [193, 343]
#     cost_astar: 297.0
# ic| s: 193
#     d: 343
#     path_dijkstra: [193, 343]
#     cost_dijkstra: 297.0
#     path_astar: [193, 343]
#     cost_astar: 297.0
# ic| s: 754
#     d: 929
#     path_dijkstra: [754, 121, 929]
#     cost_dijkstra: 483.0
#     path_astar: [754, 121, 929]
#     cost_astar: 483.0
# ic| s: 754
#     d: 929
#     path_dijkstra: [754, 121, 929]
#     cost_dijkstra: 483.0
#     path_astar: [754, 121, 929]
#     cost_astar: 483.0
# ic| s: 507
#     d: 551
#     path_dijkstra: [507, 791, 966, 551]
#     cost_dijkstra: 802.0
#     path_astar: [507, 791, 3, 551]
#     cost_astar: 802.0
# ic| s: 507
#     d: 551
#     path_dijkstra: [507, 791, 966, 551]
#     cost_dijkstra: 802.0
#     path_astar: [507, 791, 3, 551]
#     cost_astar: 802.0
# ic| s: 496
#     d: 622
#     path_dijkstra: [496, 622]
#     cost_dijkstra: 439.0
#     path_astar: [496, 622]
#     cost_astar: 439.0
# ic| s: 496
#     d: 622
#     path_dijkstra: [496, 622]
#     cost_dijkstra: 439.0
#     path_astar: [496, 622]
#     cost_astar: 439.0
# ic| s: 311
#     d: 391
#     path_dijkstra: [311, 287, 873, 391]
#     cost_dijkstra: 548.0
#     path_astar: [311, 287, 873, 391]
#     cost_astar: 548.0
# ic| s: 311
#     d: 391
#     path_dijkstra: [311, 287, 873, 391]
#     cost_dijkstra: 548.0
#     path_astar: [311, 287, 873, 391]
#     cost_astar: 548.0
# ic| s: 868
#     d: 979
#     path_dijkstra: [868, 152, 979]
#     cost_dijkstra: 399.0
#     path_astar: [868, 152, 979]
#     cost_astar: 399.0
# ic| s: 868
#     d: 979
#     path_dijkstra: [868, 152, 979]
#     cost_dijkstra: 399.0
#     path_astar: [868, 152, 979]
#     cost_astar: 399.0
# ic| s: 253
#     d: 690
#     path_dijkstra: [253, 438, 240, 690]
#     cost_dijkstra: 809.0
#     path_astar: [253, 438, 240, 690]
#     cost_astar: 809.0
# ic| s: 253
#     d: 690
#     path_dijkstra: [253, 438, 240, 690]
#     cost_dijkstra: 809.0
#     path_astar: [253, 438, 240, 690]
#     cost_astar: 809.0
# ic| s: 316
#     d: 593
#     path_dijkstra: [316, 736, 593]
#     cost_dijkstra: 715.0
#     path_astar: [316, 104, 19, 5, 593]
#     cost_astar: 715.0
# ic| s: 316
#     d: 593
#     path_dijkstra: [316, 736, 593]
#     cost_dijkstra: 715.0
#     path_astar: [316, 104, 19, 5, 593]
#     cost_astar: 715.0
# ic| s: 640
#     d: 938
#     path_dijkstra: [640, 938]
#     cost_dijkstra: 125.0
#     path_astar: [640, 938]
#     cost_astar: 125.0
# ic| s: 640
#     d: 938
#     path_dijkstra: [640, 938]
#     cost_dijkstra: 125.0
#     path_astar: [640, 938]
#     cost_astar: 125.0
# ic| s: 788
#     d: 854
#     path_dijkstra: [788, 990, 854]
#     cost_dijkstra: 569.0
#     path_astar: [788, 990, 854]
#     cost_astar: 569.0
# ic| s: 788
#     d: 854
#     path_dijkstra: [788, 990, 854]
#     cost_dijkstra: 569.0
#     path_astar: [788, 990, 854]
#     cost_astar: 569.0
# ic| s: 455
#     d: 629
#     path_dijkstra: [455, 629]
#     cost_dijkstra: 267.0
#     path_astar: [455, 629]
#     cost_astar: 267.0
# ic| s: 455
#     d: 629
#     path_dijkstra: [455, 629]
#     cost_dijkstra: 267.0
#     path_astar: [455, 629]
#     cost_astar: 267.0
# ic| s: 105
#     d: 206
#     path_dijkstra: [105, 206]
#     cost_dijkstra: 681.0
#     path_astar: [105, 206]
#     cost_astar: 681.0
# ic| s: 105
#     d: 206
#     path_dijkstra: [105, 206]
#     cost_dijkstra: 681.0
#     path_astar: [105, 206]
#     cost_astar: 681.0
# ic| s: 174
#     d: 452
#     path_dijkstra: [174, 10, 806, 839, 408, 715, 452]
#     cost_dijkstra: 667.0
#     path_astar: [174, 10, 806, 839, 408, 715, 452]
#     cost_astar: 667.0
# ic| s: 174
#     d: 452
#     path_dijkstra: [174, 10, 806, 839, 408, 715, 452]
#     cost_dijkstra: 667.0
#     path_astar: [174, 10, 806, 839, 408, 715, 452]
#     cost_astar: 667.0
# ic| s: 162
#     d: 347
#     path_dijkstra: [162, 347]
#     cost_dijkstra: 137.0
#     path_astar: [162, 347]
#     cost_astar: 137.0
# ic| s: 162
#     d: 347
#     path_dijkstra: [162, 347]
#     cost_dijkstra: 137.0
#     path_astar: [162, 347]
#     cost_astar: 137.0
# ic| s: 380
#     d: 832
#     path_dijkstra: [380, 94, 510, 832]
#     cost_dijkstra: 729.0
#     path_astar: [380, 94, 510, 832]
#     cost_astar: 729.0
# ic| s: 380
#     d: 832
#     path_dijkstra: [380, 94, 510, 832]
#     cost_dijkstra: 729.0
#     path_astar: [380, 94, 510, 832]
#     cost_astar: 729.0
# ic| s: 728
#     d: 758
#     path_dijkstra: [728, 722, 444, 758]
#     cost_dijkstra: 530.0
#     path_astar: [728, 722, 444, 758]
#     cost_astar: 530.0
# ic| s: 728
#     d: 758
#     path_dijkstra: [728, 722, 444, 758]
#     cost_dijkstra: 530.0
#     path_astar: [728, 722, 444, 758]
#     cost_astar: 530.0
# ic| s: 310
#     d: 325
#     path_dijkstra: [310, 325]
#     cost_dijkstra: 553.0
#     path_astar: [310, 325]
#     cost_astar: 553.0
# ic| s: 310
#     d: 325
#     path_dijkstra: [310, 325]
#     cost_dijkstra: 553.0
#     path_astar: [310, 325]
#     cost_astar: 553.0
# ic| s: 665
#     d: 762
#     path_dijkstra: [665, 762]
#     cost_dijkstra: 328.0
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 888
#     d: 914
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 314
#     d: 684
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 233
#     d: 725
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 381
#     d: 959
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 676
#     d: 871
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 18
#     d: 291
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 295
#     d: 733
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 136
#     d: 718
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 531
#     d: 707
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 595
#     d: 975
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 241
#     d: 366
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 248
#     d: 344
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 449
#     d: 992
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 95
#     d: 361
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 215
#     d: 914
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 348
#     d: 803
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 728
#     d: 890
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 487
#     d: 911
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 568
#     d: 927
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 459
#     d: 654
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 665
#     d: 762
#     path_dijkstra: [665, 762]
#     cost_dijkstra: 328.0
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 888
#     d: 914
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 314
#     d: 684
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 233
#     d: 725
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 381
#     d: 959
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 676
#     d: 871
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 18
#     d: 291
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 295
#     d: 733
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 136
#     d: 718
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 531
#     d: 707
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 595
#     d: 975
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 241
#     d: 366
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 248
#     d: 344
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 449
#     d: 992
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 95
#     d: 361
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 215
#     d: 914
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 348
#     d: 803
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 728
#     d: 890
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 487
#     d: 911
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 568
#     d: 927
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 459
#     d: 654
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 525
#     d: 638
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 220
#     d: 983
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 46
#     d: 461
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 265
#     d: 653
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 449
#     d: 475
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 316
#     d: 964
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 58
#     d: 357
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 572
#     d: 579
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 89
#     d: 920
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 326
#     d: 749
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 655
#     d: 872
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 233
#     d: 673
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 218
#     d: 350
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 302
#     d: 796
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 519
#     d: 640
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 15
#     d: 641
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 287
#     d: 674
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 23
#     d: 99
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 177
#     d: 689
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 488
#     d: 579
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 6
#     d: 7
#     path_dijkstra: [6, 7]
#     cost_dijkstra: 628.0
#     path_astar: [6, 7]
#     cost_astar: 628.0
# ic| s: 5
#     d: 8
#     path_dijkstra: [5, 6, 8]
#     cost_dijkstra: 1056.0
#     path_astar: [5, 6, 8]
#     cost_astar: 1056.0
# ic| s: 7
#     d: 9
#     path_dijkstra: [7, 9]
#     cost_dijkstra: 558.0
#     path_astar: [7, 9]
#     cost_astar: 558.0
# ic| s: 3
#     d: 5
#     path_dijkstra: [3, 5]
#     cost_dijkstra: 415.0
#     path_astar: [3, 5]
#     cost_astar: 415.0
# ic| s: 1
#     d: 3
#     path_dijkstra: [1, 3]
#     cost_dijkstra: 132.0
#     path_astar: [1, 3]
#     cost_astar: 132.0
# ic| s: 6
#     d: 8
#     path_dijkstra: [6, 8]
#     cost_dijkstra: 764.0
#     path_astar: [6, 8]
#     cost_astar: 764.0
# ic| s: 4
#     d: 7
#     path_dijkstra: [4, 8, 7]
#     cost_dijkstra: 774.0
#     path_astar: [4, 8, 7]
#     cost_astar: 774.0
# ic| s: 1
#     d: 7
#     path_dijkstra: [1, 7]
#     cost_dijkstra: 627.0
#     path_astar: [1, 7]
#     cost_astar: 627.0
# ic| s: 0
#     d: 1
#     path_dijkstra: [0, 1]
#     cost_dijkstra: 272.0
#     path_astar: [0, 1]
#     cost_astar: 272.0
# ic| s: 1
#     d: 5
#     path_dijkstra: [1, 5]
#     cost_dijkstra: 539.0
#     path_astar: [1, 5]
#     cost_astar: 539.0
# ic| s: 4
#     d: 9
#     path_dijkstra: [4, 0, 9]
#     cost_dijkstra: 846.0
#     path_astar: [4, 0, 9]
#     cost_astar: 846.0
# ic| s: 7
#     d: 8
#     path_dijkstra: [7, 8]
#     cost_dijkstra: 198.0
#     path_astar: [7, 8]
#     cost_astar: 198.0
# ic| s: 6
#     d: 9
#     path_dijkstra: [6, 9]
#     cost_dijkstra: 265.0
#     path_astar: [6, 9]
#     cost_astar: 265.0
# ic| s: 2
#     d: 8
#     path_dijkstra: [2, 8]
#     cost_dijkstra: 1021.0
#     path_astar: [2, 8]
#     cost_astar: 1021.0
# ic| s: 4
#     d: 5
#     path_dijkstra: [4, 5]
#     cost_dijkstra: 535.0
#     path_astar: [4, 5]
#     cost_astar: 535.0
# ic| s: 3
#     d: 7
#     path_dijkstra: [3, 7]
#     cost_dijkstra: 643.0
#     path_astar: [3, 7]
#     cost_astar: 643.0
# ic| s: 2
#     d: 4
#     path_dijkstra: [2, 4]
#     cost_dijkstra: 526.0
#     path_astar: [2, 4]
#     cost_astar: 526.0
# ic| s: 1
#     d: 4
#     path_dijkstra: [1, 4]
#     cost_dijkstra: 771.0
#     path_astar: [1, 4]
#     cost_astar: 771.0
# ic| s: 4
#     d: 8
#     path_dijkstra: [4, 8]
#     cost_dijkstra: 576.0
#     path_astar: [4, 8]
#     cost_astar: 576.0
# ic| s: 0
#     d: 9
#     path_dijkstra: [0, 9]
#     cost_dijkstra: 200.0
#     path_astar: [0, 9]
#     cost_astar: 200.0
# ic| s: 35
#     d: 38
#     path_dijkstra: [35, 18, 38]
#     cost_dijkstra: 356.0
#     path_astar: [35, 18, 38]
#     cost_astar: 356.0
# ic| s: 0
#     d: 12
#     path_dijkstra: [0, 30, 46, 7, 12]
#     cost_dijkstra: 841.0
#     path_astar: [0, 30, 46, 7, 12]
#     cost_astar: 841.0
# ic| s: 525
#     d: 638
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 220
#     d: 983
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 46
#     d: 461
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 265
#     d: 653
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 449
#     d: 475
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 316
#     d: 964
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 58
#     d: 357
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 572
#     d: 579
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 89
#     d: 920
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 326
#     d: 749
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 655
#     d: 872
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 233
#     d: 673
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 218
#     d: 350
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 302
#     d: 796
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 519
#     d: 640
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 15
#     d: 641
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 287
#     d: 674
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 23
#     d: 99
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 177
#     d: 689
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 488
#     d: 579
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [665, 762]
#     cost_astar: 328.0
# ic| s: 6
#     d: 7
#     path_dijkstra: [6, 7]
#     cost_dijkstra: 628.0
#     path_astar: [6, 7]
#     cost_astar: 628.0
# ic| s: 5
#     d: 8
#     path_dijkstra: [5, 6, 8]
#     cost_dijkstra: 1056.0
#     path_astar: [5, 6, 8]
#     cost_astar: 1056.0
# ic| s: 7
#     d: 9
#     path_dijkstra: [7, 9]
#     cost_dijkstra: 558.0
#     path_astar: [7, 9]
#     cost_astar: 558.0
# ic| s: 3
#     d: 5
#     path_dijkstra: [3, 5]
#     cost_dijkstra: 415.0
#     path_astar: [3, 5]
#     cost_astar: 415.0
# ic| s: 1
#     d: 3
#     path_dijkstra: [1, 3]
#     cost_dijkstra: 132.0
#     path_astar: [1, 3]
#     cost_astar: 132.0
# ic| s: 6
#     d: 8
#     path_dijkstra: [6, 8]
#     cost_dijkstra: 764.0
#     path_astar: [6, 8]
#     cost_astar: 764.0
# ic| s: 4
#     d: 7
#     path_dijkstra: [4, 8, 7]
#     cost_dijkstra: 774.0
#     path_astar: [4, 8, 7]
#     cost_astar: 774.0
# ic| s: 1
#     d: 7
#     path_dijkstra: [1, 7]
#     cost_dijkstra: 627.0
#     path_astar: [1, 7]
#     cost_astar: 627.0
# ic| s: 0
#     d: 1
#     path_dijkstra: [0, 1]
#     cost_dijkstra: 272.0
#     path_astar: [0, 1]
#     cost_astar: 272.0
# ic| s: 1
#     d: 5
#     path_dijkstra: [1, 5]
#     cost_dijkstra: 539.0
#     path_astar: [1, 5]
#     cost_astar: 539.0
# ic| s: 4
#     d: 9
#     path_dijkstra: [4, 0, 9]
#     cost_dijkstra: 846.0
#     path_astar: [4, 0, 9]
#     cost_astar: 846.0
# ic| s: 7
#     d: 8
#     path_dijkstra: [7, 8]
#     cost_dijkstra: 198.0
#     path_astar: [7, 8]
#     cost_astar: 198.0
# ic| s: 6
#     d: 9
#     path_dijkstra: [6, 9]
#     cost_dijkstra: 265.0
#     path_astar: [6, 9]
#     cost_astar: 265.0
# ic| s: 2
#     d: 8
#     path_dijkstra: [2, 8]
#     cost_dijkstra: 1021.0
#     path_astar: [2, 8]
#     cost_astar: 1021.0
# ic| s: 4
#     d: 5
#     path_dijkstra: [4, 5]
#     cost_dijkstra: 535.0
#     path_astar: [4, 5]
#     cost_astar: 535.0
# ic| s: 3
#     d: 7
#     path_dijkstra: [3, 7]
#     cost_dijkstra: 643.0
#     path_astar: [3, 7]
#     cost_astar: 643.0
# ic| s: 2
#     d: 4
#     path_dijkstra: [2, 4]
#     cost_dijkstra: 526.0
#     path_astar: [2, 4]
#     cost_astar: 526.0
# ic| s: 1
#     d: 4
#     path_dijkstra: [1, 4]
#     cost_dijkstra: 771.0
#     path_astar: [1, 4]
#     cost_astar: 771.0
# ic| s: 4
#     d: 8
#     path_dijkstra: [4, 8]
#     cost_dijkstra: 576.0
#     path_astar: [4, 8]
#     cost_astar: 576.0
# ic| s: 0
#     d: 9
#     path_dijkstra: [0, 9]
#     cost_dijkstra: 200.0
#     path_astar: [0, 9]
#     cost_astar: 200.0
# ic| s: 35
#     d: 38
#     path_dijkstra: [35, 18, 38]
#     cost_dijkstra: 356.0
#     path_astar: [35, 18, 38]
#     cost_astar: 356.0
# ic| s: 0
#     d: 12
#     path_dijkstra: [0, 30, 46, 7, 12]
#     cost_dijkstra: 841.0
#     path_astar: [0, 30, 46, 7, 12]
#     cost_astar: 841.0
# ic| s: 19
#     d: 45
#     path_dijkstra: [19, 44, 38, 20, 5, 45]
#     cost_dijkstra: 1045.0
#     path_astar: [19, 44, 38, 20, 5, 45]
#     cost_astar: 1045.0
# ic| s: 30
#     d: 45
#     path_dijkstra: [30, 5, 45]
#     cost_dijkstra: 862.0
#     path_astar: [30, 5, 45]
#     cost_astar: 862.0
# ic| s: 5
#     d: 35
#     path_dijkstra: [5, 38, 35]
#     cost_dijkstra: 541.0
#     path_astar: [5, 38, 35]
#     cost_astar: 541.0
# ic| s: 31
#     d: 40
#     path_dijkstra: [31, 40]
#     cost_dijkstra: 372.0
#     path_astar: [31, 40]
#     cost_astar: 372.0
# ic| s: 37
#     d: 40
#     path_dijkstra: [37, 16, 38, 40]
#     cost_dijkstra: 1025.0
#     path_astar: [37, 16, 38, 40]
#     cost_astar: 1025.0
# ic| s: 9
#     d: 25
#     path_dijkstra: [9, 17, 8, 25]
#     cost_dijkstra: 1080.0
#     path_astar: [9, 17, 8, 25]
#     cost_astar: 1080.0
# ic| s: 22
#     d: 48
#     path_dijkstra: [22, 44, 48]
#     cost_dijkstra: 1196.0
#     path_astar: [22, 44, 48]
#     cost_astar: 1196.0
# ic| s: 2
#     d: 20
#     path_dijkstra: [2, 18, 38, 20]
#     cost_dijkstra: 972.0
#     path_astar: [2, 18, 38, 20]
#     cost_astar: 972.0
# ic| s: 27
#     d: 41
#     path_dijkstra: [27, 26, 41]
#     cost_dijkstra: 641.0
#     path_astar: [27, 26, 41]
#     cost_astar: 641.0
# ic| s: 18
#     d: 36
#     path_dijkstra: [18, 38, 7, 36]
#     cost_dijkstra: 1118.0
#     path_astar: [18, 38, 7, 36]
#     cost_astar: 1118.0
# ic| s: 38
#     d: 47
#     path_dijkstra: [38, 4, 47]
#     cost_dijkstra: 519.0
#     path_astar: [38, 4, 47]
#     cost_astar: 519.0
# ic| s: 36
#     d: 38
#     path_dijkstra: [36, 40, 38]
#     cost_dijkstra: 706.0
#     path_astar: [36, 40, 38]
#     cost_astar: 706.0
# ic| s: 9
#     d: 14
#     path_dijkstra: [9, 31, 38, 14]
#     cost_dijkstra: 726.0
#     path_astar: [9, 31, 38, 14]
#     cost_astar: 726.0
# ic| s: 29
#     d: 48
#     path_dijkstra: [29, 38, 35, 48]
#     cost_dijkstra: 1187.0
#     path_astar: [29, 38, 35, 48]
#     cost_astar: 1187.0
# ic| s: 21
#     d: 49
#     path_dijkstra: [21, 31, 49]
#     cost_dijkstra: 961.0
#     path_astar: [21, 31, 49]
#     cost_astar: 961.0
# ic| s: 27
#     d: 49
#     path_dijkstra: [27, 49]
#     cost_dijkstra: 614.0
#     path_astar: [27, 49]
#     cost_astar: 614.0
# ic| s: 18
#     d: 20
#     path_dijkstra: [18, 38, 20]
#     cost_dijkstra: 471.0
#     path_astar: [18, 38, 20]
#     cost_astar: 471.0
# ic| s: 22
#     d: 24
#     path_dijkstra: [22, 5, 24]
#     cost_dijkstra: 1323.0
#     path_astar: [22, 5, 24]
#     cost_astar: 1323.0
# ic| s: 2
#     d: 8
#     path_dijkstra: [2, 7, 8]
#     cost_dijkstra: 1349.0
#     path_astar: [2, 7, 8]
#     cost_astar: 1349.0
# ic| s: 0
#     d: 1
#     path_dijkstra: [0, 1]
#     cost_dijkstra: 556.0
#     path_astar: [0, 1]
#     cost_astar: 556.0
# ic| s: 4
#     d: 9
#     path_dijkstra: [4, 9]
#     cost_dijkstra: 1072.0
#     path_astar: [4, 9]
#     cost_astar: 1072.0
# ic| s: 7
#     d: 8
#     path_dijkstra: [7, 8]
#     cost_dijkstra: 292.0
#     path_astar: [7, 8]
#     cost_astar: 292.0
# ic| s: 6
#     d: 7
#     path_dijkstra: [6, 7]
#     cost_dijkstra: 998.0
#     path_astar: [6, 7]
#     cost_astar: 998.0
# ic| s: 6
#     d: 8
#     path_dijkstra: [6, 8]
#     cost_dijkstra: 893.0
#     path_astar: [6, 8]
#     cost_astar: 893.0
# ic| s: 2
#     d: 7
#     path_dijkstra: [2, 7]
#     cost_dijkstra: 1057.0
#     path_astar: [2, 7]
#     cost_astar: 1057.0
# ic| s: 3
#     d: 9
#     path_dijkstra: [3, 9]
#     cost_dijkstra: 260.0
#     path_astar: [3, 9]
#     cost_astar: 260.0
# ic| s: 0
#     d: 2
#     path_dijkstra: [0, 7, 2]
#     cost_dijkstra: 1611.0
#     path_astar: [0, 7, 2]
#     cost_astar: 1611.0
# ic| s: 1
#     d: 7
#     path_dijkstra: [1, 7]
#     cost_dijkstra: 1008.0
#     path_astar: [1, 7]
#     cost_astar: 1008.0
# ic| s: 1
#     d: 4
#     path_dijkstra: [1, 6, 4]
#     cost_dijkstra: 1007.0
#     path_astar: [1, 6, 4]
#     cost_astar: 1007.0
# ic| s: 6
#     d: 9
#     path_dijkstra: [6, 3, 9]
#     cost_dijkstra: 516.0
#     path_astar: [6, 3, 9]
#     cost_astar: 516.0
# ic| s: 0
#     d: 6
#     path_dijkstra: [0, 6]
#     cost_dijkstra: 779.0
#     path_astar: [0, 6]
#     cost_astar: 779.0
# ic| s: 1
#     d: 9
#     path_dijkstra: [1, 9]
#     cost_dijkstra: 608.0
#     path_astar: [1, 9]
#     cost_astar: 608.0
# ic| s: 5
#     d: 7
#     path_dijkstra: [5, 4, 7]
#     cost_dijkstra: 1210.0
#     path_astar: [5, 4, 7]
#     cost_astar: 1210.0
# ic| s: 3
#     d: 6
#     path_dijkstra: [3, 6]
#     cost_dijkstra: 490.0
#     path_astar: [3, 6]
#     cost_astar: 490.0
# ic| s: 5
#     d: 9
#     path_dijkstra: [5, 3, 9]
#     cost_dijkstra: 862.0
#     path_astar: [5, 3, 9]
#     cost_astar: 862.0
# ic| s: 0
#     d: 3
#     path_dijkstra: [0, 1, 3]
#     cost_dijkstra: 984.0
#     path_astar: [0, 1, 3]
#     cost_astar: 984.0
# ic| s: 3
#     d: 7
#     path_dijkstra: [3, 0, 7]
#     cost_dijkstra: 935.0
#     path_astar: [3, 0, 7]
#     cost_astar: 935.0
# ic| s: 7
#     d: 9
#     path_dijkstra: [7, 3, 9]
#     cost_dijkstra: 1208.0
#     path_astar: [7, 3, 9]
#     cost_astar: 1208.0
# ic| s: 49
#     d: 85
#     path_dijkstra: [49, 54, 85]
#     cost_dijkstra: 559.0
#     path_astar: [49, 54, 85]
#     cost_astar: 559.0
# ic| s: 1
#     d: 22
#     path_dijkstra: [1, 22]
#     cost_dijkstra: 373.0
#     path_astar: [1, 22]
#     cost_astar: 373.0
# ic| s: 26
#     d: 81
#     path_dijkstra: [26, 81]
#     cost_dijkstra: 914.0
#     path_astar: [26, 81]
#     cost_astar: 914.0
# ic| s: 23
#     d: 44
#     path_dijkstra: [23, 16, 44]
#     cost_dijkstra: 563.0
#     path_astar: [23, 16, 44]
#     cost_astar: 563.0
# ic| s: 25
#     d: 51
#     path_dijkstra: [25, 18, 51]
#     cost_dijkstra: 1008.0
#     path_astar: [25, 18, 51]
#     cost_astar: 1008.0
# ic| s: 9
#     d: 51
#     path_dijkstra: [9, 52, 98, 51]
#     cost_dijkstra: 798.0
#     path_astar: [9, 52, 98, 51]
#     cost_astar: 798.0
# ic| s: 16
#     d: 65
#     path_dijkstra: [16, 99, 47, 65]
#     cost_dijkstra: 899.0
#     path_astar: [16, 99, 47, 65]
#     cost_astar: 899.0
# ic| s: 34
#     d: 51
#     path_dijkstra: [34, 51]
#     cost_dijkstra: 750.0
#     path_astar: [34, 51]
#     cost_astar: 750.0
# ic| s: 27
#     d: 84
#     path_dijkstra: [27, 84]
#     cost_dijkstra: 478.0
#     path_astar: [27, 84]
#     cost_astar: 478.0
# ic| s: 5
#     d: 90
#     path_dijkstra: [5, 90]
#     cost_dijkstra: 694.0
#     path_astar: [5, 90]
#     cost_astar: 694.0
# ic| s: 19
#     d: 45
#     path_dijkstra: [19, 44, 38, 20, 5, 45]
#     cost_dijkstra: 1045.0
#     path_astar: [19, 44, 38, 20, 5, 45]
#     cost_astar: 1045.0
# ic| s: 30
#     d: 45
#     path_dijkstra: [30, 5, 45]
#     cost_dijkstra: 862.0
#     path_astar: [30, 5, 45]
#     cost_astar: 862.0
# ic| s: 5
#     d: 35
#     path_dijkstra: [5, 38, 35]
#     cost_dijkstra: 541.0
#     path_astar: [5, 38, 35]
#     cost_astar: 541.0
# ic| s: 31
#     d: 40
#     path_dijkstra: [31, 40]
#     cost_dijkstra: 372.0
#     path_astar: [31, 40]
#     cost_astar: 372.0
# ic| s: 37
#     d: 40
#     path_dijkstra: [37, 16, 38, 40]
#     cost_dijkstra: 1025.0
#     path_astar: [37, 16, 38, 40]
#     cost_astar: 1025.0
# ic| s: 9
#     d: 25
#     path_dijkstra: [9, 17, 8, 25]
#     cost_dijkstra: 1080.0
#     path_astar: [9, 17, 8, 25]
#     cost_astar: 1080.0
# ic| s: 22
#     d: 48
#     path_dijkstra: [22, 44, 48]
#     cost_dijkstra: 1196.0
#     path_astar: [22, 44, 48]
#     cost_astar: 1196.0
# ic| s: 2
#     d: 20
#     path_dijkstra: [2, 18, 38, 20]
#     cost_dijkstra: 972.0
#     path_astar: [2, 18, 38, 20]
#     cost_astar: 972.0
# ic| s: 27
#     d: 41
#     path_dijkstra: [27, 26, 41]
#     cost_dijkstra: 641.0
#     path_astar: [27, 26, 41]
#     cost_astar: 641.0
# ic| s: 18
#     d: 36
#     path_dijkstra: [18, 38, 7, 36]
#     cost_dijkstra: 1118.0
#     path_astar: [18, 38, 7, 36]
#     cost_astar: 1118.0
# ic| s: 38
#     d: 47
#     path_dijkstra: [38, 4, 47]
#     cost_dijkstra: 519.0
#     path_astar: [38, 4, 47]
#     cost_astar: 519.0
# ic| s: 36
#     d: 38
#     path_dijkstra: [36, 40, 38]
#     cost_dijkstra: 706.0
#     path_astar: [36, 40, 38]
#     cost_astar: 706.0
# ic| s: 9
#     d: 14
#     path_dijkstra: [9, 31, 38, 14]
#     cost_dijkstra: 726.0
#     path_astar: [9, 31, 38, 14]
#     cost_astar: 726.0
# ic| s: 29
#     d: 48
#     path_dijkstra: [29, 38, 35, 48]
#     cost_dijkstra: 1187.0
#     path_astar: [29, 38, 35, 48]
#     cost_astar: 1187.0
# ic| s: 21
#     d: 49
#     path_dijkstra: [21, 31, 49]
#     cost_dijkstra: 961.0
#     path_astar: [21, 31, 49]
#     cost_astar: 961.0
# ic| s: 27
#     d: 49
#     path_dijkstra: [27, 49]
#     cost_dijkstra: 614.0
#     path_astar: [27, 49]
#     cost_astar: 614.0
# ic| s: 18
#     d: 20
#     path_dijkstra: [18, 38, 20]
#     cost_dijkstra: 471.0
#     path_astar: [18, 38, 20]
#     cost_astar: 471.0
# ic| s: 22
#     d: 24
#     path_dijkstra: [22, 5, 24]
#     cost_dijkstra: 1323.0
#     path_astar: [22, 5, 24]
#     cost_astar: 1323.0
# ic| s: 2
#     d: 8
#     path_dijkstra: [2, 7, 8]
#     cost_dijkstra: 1349.0
#     path_astar: [2, 7, 8]
#     cost_astar: 1349.0
# ic| s: 0
#     d: 1
#     path_dijkstra: [0, 1]
#     cost_dijkstra: 556.0
#     path_astar: [0, 1]
#     cost_astar: 556.0
# ic| s: 4
#     d: 9
#     path_dijkstra: [4, 9]
#     cost_dijkstra: 1072.0
#     path_astar: [4, 9]
#     cost_astar: 1072.0
# ic| s: 7
#     d: 8
#     path_dijkstra: [7, 8]
#     cost_dijkstra: 292.0
#     path_astar: [7, 8]
#     cost_astar: 292.0
# ic| s: 6
#     d: 7
#     path_dijkstra: [6, 7]
#     cost_dijkstra: 998.0
#     path_astar: [6, 7]
#     cost_astar: 998.0
# ic| s: 6
#     d: 8
#     path_dijkstra: [6, 8]
#     cost_dijkstra: 893.0
#     path_astar: [6, 8]
#     cost_astar: 893.0
# ic| s: 2
#     d: 7
#     path_dijkstra: [2, 7]
#     cost_dijkstra: 1057.0
#     path_astar: [2, 7]
#     cost_astar: 1057.0
# ic| s: 3
#     d: 9
#     path_dijkstra: [3, 9]
#     cost_dijkstra: 260.0
#     path_astar: [3, 9]
#     cost_astar: 260.0
# ic| s: 0
#     d: 2
#     path_dijkstra: [0, 7, 2]
#     cost_dijkstra: 1611.0
#     path_astar: [0, 7, 2]
#     cost_astar: 1611.0
# ic| s: 1
#     d: 7
#     path_dijkstra: [1, 7]
#     cost_dijkstra: 1008.0
#     path_astar: [1, 7]
#     cost_astar: 1008.0
# ic| s: 1
#     d: 4
#     path_dijkstra: [1, 6, 4]
#     cost_dijkstra: 1007.0
#     path_astar: [1, 6, 4]
#     cost_astar: 1007.0
# ic| s: 6
#     d: 9
#     path_dijkstra: [6, 3, 9]
#     cost_dijkstra: 516.0
#     path_astar: [6, 3, 9]
#     cost_astar: 516.0
# ic| s: 0
#     d: 6
#     path_dijkstra: [0, 6]
#     cost_dijkstra: 779.0
#     path_astar: [0, 6]
#     cost_astar: 779.0
# ic| s: 1
#     d: 9
#     path_dijkstra: [1, 9]
#     cost_dijkstra: 608.0
#     path_astar: [1, 9]
#     cost_astar: 608.0
# ic| s: 5
#     d: 7
#     path_dijkstra: [5, 4, 7]
#     cost_dijkstra: 1210.0
#     path_astar: [5, 4, 7]
#     cost_astar: 1210.0
# ic| s: 3
#     d: 6
#     path_dijkstra: [3, 6]
#     cost_dijkstra: 490.0
#     path_astar: [3, 6]
#     cost_astar: 490.0
# ic| s: 5
#     d: 9
#     path_dijkstra: [5, 3, 9]
#     cost_dijkstra: 862.0
#     path_astar: [5, 3, 9]
#     cost_astar: 862.0
# ic| s: 0
#     d: 3
#     path_dijkstra: [0, 1, 3]
#     cost_dijkstra: 984.0
#     path_astar: [0, 1, 3]
#     cost_astar: 984.0
# ic| s: 3
#     d: 7
#     path_dijkstra: [3, 0, 7]
#     cost_dijkstra: 935.0
#     path_astar: [3, 0, 7]
#     cost_astar: 935.0
# ic| s: 7
#     d: 9
#     path_dijkstra: [7, 3, 9]
#     cost_dijkstra: 1208.0
#     path_astar: [7, 3, 9]
#     cost_astar: 1208.0
# ic| s: 49
#     d: 85
#     path_dijkstra: [49, 54, 85]
#     cost_dijkstra: 559.0
#     path_astar: [49, 54, 85]
#     cost_astar: 559.0
# ic| s: 1
#     d: 22
#     path_dijkstra: [1, 22]
#     cost_dijkstra: 373.0
#     path_astar: [1, 22]
#     cost_astar: 373.0
# ic| s: 26
#     d: 81
#     path_dijkstra: [26, 81]
#     cost_dijkstra: 914.0
#     path_astar: [26, 81]
#     cost_astar: 914.0
# ic| s: 23
#     d: 44
#     path_dijkstra: [23, 16, 44]
#     cost_dijkstra: 563.0
#     path_astar: [23, 16, 44]
#     cost_astar: 563.0
# ic| s: 25
#     d: 51
#     path_dijkstra: [25, 18, 51]
#     cost_dijkstra: 1008.0
#     path_astar: [25, 18, 51]
#     cost_astar: 1008.0
# ic| s: 9
#     d: 51
#     path_dijkstra: [9, 52, 98, 51]
#     cost_dijkstra: 798.0
#     path_astar: [9, 52, 98, 51]
#     cost_astar: 798.0
# ic| s: 16
#     d: 65
#     path_dijkstra: [16, 99, 47, 65]
#     cost_dijkstra: 899.0
#     path_astar: [16, 99, 47, 65]
#     cost_astar: 899.0
# ic| s: 34
#     d: 51
#     path_dijkstra: [34, 51]
#     cost_dijkstra: 750.0
#     path_astar: [34, 51]
#     cost_astar: 750.0
# ic| s: 27
#     d: 84
#     path_dijkstra: [27, 84]
#     cost_dijkstra: 478.0
#     path_astar: [27, 84]
#     cost_astar: 478.0
# ic| s: 5
#     d: 90
#     path_dijkstra: [5, 90]
#     cost_dijkstra: 694.0
#     path_astar: [5, 90]
#     cost_astar: 694.0
# ic| s: 14
#     d: 91
#     path_dijkstra: [14, 59, 91]
#     cost_dijkstra: 743.0
#     path_astar: [14, 59, 91]
#     cost_astar: 743.0
# ic| s: 14
#     d: 27
#     path_dijkstra: [14, 59, 27]
#     cost_dijkstra: 629.0
#     path_astar: [14, 59, 27]
#     cost_astar: 629.0
# ic| s: 23
#     d: 90
#     path_dijkstra: [23, 70, 26, 90]
#     cost_dijkstra: 975.0
#     path_astar: [23, 70, 26, 90]
#     cost_astar: 975.0
# ic| s: 64
#     d: 65
#     path_dijkstra: [64, 47, 65]
#     cost_dijkstra: 553.0
#     path_astar: [64, 47, 65]
#     cost_astar: 553.0
# ic| s: 14
#     d: 97
#     path_dijkstra: [14, 19, 29, 97]
#     cost_dijkstra: 828.0
#     path_astar: [14, 19, 29, 97]
#     cost_astar: 828.0
# ic| s: 25
#     d: 86
#     path_dijkstra: [25, 73, 86]
#     cost_dijkstra: 1108.0
#     path_astar: [25, 73, 86]
#     cost_astar: 1108.0
# ic| s: 28
#     d: 47
#     path_dijkstra: [28, 70, 47]
#     cost_dijkstra: 485.0
#     path_astar: [28, 70, 47]
#     cost_astar: 485.0
# ic| s: 49
#     d: 99
#     path_dijkstra: [49, 54, 99]
#     cost_dijkstra: 757.0
#     path_astar: [49, 54, 99]
#     cost_astar: 757.0
# ic| s: 31
#     d: 65
#     path_dijkstra: [31, 5, 65]
#     cost_dijkstra: 499.0
#     path_astar: [31, 5, 65]
#     cost_astar: 499.0
# ic| s: 57
#     d: 78
#     path_dijkstra: [57, 78]
#     cost_dijkstra: 351.0
#     path_astar: [57, 78]
#     cost_astar: 351.0
# ic| s: 14
#     d: 91
#     path_dijkstra: [14, 59, 91]
#     cost_dijkstra: 743.0
#     path_astar: [14, 59, 91]
#     cost_astar: 743.0
# ic| s: 14
#     d: 27
#     path_dijkstra: [14, 59, 27]
#     cost_dijkstra: 629.0
#     path_astar: [14, 59, 27]
#     cost_astar: 629.0
# ic| s: 23
#     d: 90
#     path_dijkstra: [23, 70, 26, 90]
#     cost_dijkstra: 975.0
#     path_astar: [23, 70, 26, 90]
#     cost_astar: 975.0
# ic| s: 64
#     d: 65
#     path_dijkstra: [64, 47, 65]
#     cost_dijkstra: 553.0
#     path_astar: [64, 47, 65]
#     cost_astar: 553.0
# ic| s: 14
#     d: 97
#     path_dijkstra: [14, 19, 29, 97]
#     cost_dijkstra: 828.0
#     path_astar: [14, 19, 29, 97]
#     cost_astar: 828.0
# ic| s: 25
#     d: 86
#     path_dijkstra: [25, 73, 86]
#     cost_dijkstra: 1108.0
#     path_astar: [25, 73, 86]
#     cost_astar: 1108.0
# ic| s: 28
#     d: 47
#     path_dijkstra: [28, 70, 47]
#     cost_dijkstra: 485.0
#     path_astar: [28, 70, 47]
#     cost_astar: 485.0
# ic| s: 49
#     d: 99
#     path_dijkstra: [49, 54, 99]
#     cost_dijkstra: 757.0
#     path_astar: [49, 54, 99]
#     cost_astar: 757.0
# ic| s: 31
#     d: 65
#     path_dijkstra: [31, 5, 65]
#     cost_dijkstra: 499.0
#     path_astar: [31, 5, 65]
#     cost_astar: 499.0
# ic| s: 57
#     d: 78
#     path_dijkstra: [57, 78]
#     cost_dijkstra: 351.0
#     path_astar: [57, 78]
#     cost_astar: 351.0
# ic| s: 290
#     d: 878
#     path_dijkstra: [290, 636, 878]
#     cost_dijkstra: 611.0
#     path_astar: [290, 636, 878]
#     cost_astar: 611.0
# ic| s: 290
#     d: 878
#     path_dijkstra: [290, 636, 878]
#     cost_dijkstra: 611.0
#     path_astar: [290, 636, 878]
#     cost_astar: 611.0
# ic| s: 61
#     d: 821
#     path_dijkstra: [61, 454, 821]
#     cost_dijkstra: 508.0
#     path_astar: [61, 454, 821]
#     cost_astar: 508.0
# ic| s: 61
#     d: 821
#     path_dijkstra: [61, 454, 821]
#     cost_dijkstra: 508.0
#     path_astar: [61, 454, 821]
#     cost_astar: 508.0
# ic| s: 12
#     d: 482
#     path_dijkstra: [12, 991, 482]
#     cost_dijkstra: 447.0
#     path_astar: [12, 991, 482]
#     cost_astar: 447.0
# ic| s: 12
#     d: 482
#     path_dijkstra: [12, 991, 482]
#     cost_dijkstra: 447.0
#     path_astar: [12, 991, 482]
#     cost_astar: 447.0
# ic| s: 179
#     d: 870
#     path_dijkstra: [179, 640, 454, 870]
#     cost_dijkstra: 556.0
#     path_astar: [179, 640, 454, 870]
#     cost_astar: 556.0
# ic| s: 179
#     d: 870
#     path_dijkstra: [179, 640, 454, 870]
#     cost_dijkstra: 556.0
#     path_astar: [179, 640, 454, 870]
#     cost_astar: 556.0
# ic| s: 229
#     d: 232
#     path_dijkstra: [229, 60, 232]
#     cost_dijkstra: 313.0
#     path_astar: [229, 60, 232]
#     cost_astar: 313.0
# ic| s: 229
#     d: 232
#     path_dijkstra: [229, 60, 232]
#     cost_dijkstra: 313.0
#     path_astar: [229, 60, 232]
#     cost_astar: 313.0
# ic| s: 200
#     d: 311
#     path_dijkstra: [200, 347, 311]
#     cost_dijkstra: 884.0
#     path_astar: [200, 347, 311]
#     cost_astar: 884.0
# ic| s: 200
#     d: 311
#     path_dijkstra: [200, 347, 311]
#     cost_dijkstra: 884.0
#     path_astar: [200, 347, 311]
#     cost_astar: 884.0
# ic| s: 252
#     d: 813
#     path_dijkstra: [252, 682, 572, 813]
#     cost_dijkstra: 700.0
#     path_astar: [252, 682, 572, 813]
#     cost_astar: 700.0
# ic| s: 252
#     d: 813
#     path_dijkstra: [252, 682, 572, 813]
#     cost_dijkstra: 700.0
#     path_astar: [252, 682, 572, 813]
#     cost_astar: 700.0
# ic| s: 594
#     d: 749
#     path_dijkstra: [594, 531, 266, 749]
#     cost_dijkstra: 350.0
#     path_astar: [594, 531, 266, 749]
#     cost_astar: 350.0
# ic| s: 594
#     d: 749
#     path_dijkstra: [594, 531, 266, 749]
#     cost_dijkstra: 350.0
#     path_astar: [594, 531, 266, 749]
#     cost_astar: 350.0
# ic| s: 104
#     d: 151
#     path_dijkstra: [104, 249, 843, 737, 151]
#     cost_dijkstra: 479.0
#     path_astar: [104, 249, 843, 737, 151]
#     cost_astar: 479.0
# ic| s: 104
#     d: 151
#     path_dijkstra: [104, 249, 843, 737, 151]
#     cost_dijkstra: 479.0
#     path_astar: [104, 249, 843, 737, 151]
#     cost_astar: 479.0
# ic| s: 146
#     d: 364
#     path_dijkstra: [146, 40, 364]
#     cost_dijkstra: 720.0
#     path_astar: [146, 40, 364]
#     cost_astar: 720.0
# ic| s: 146
#     d: 364
#     path_dijkstra: [146, 40, 364]
#     cost_dijkstra: 720.0
#     path_astar: [146, 40, 364]
#     cost_astar: 720.0
# ic| s: 58
#     d: 792
#     path_dijkstra: [58, 840, 792]
#     cost_dijkstra: 342.0
#     path_astar: [58, 840, 792]
#     cost_astar: 342.0
# ic| s: 58
#     d: 792
#     path_dijkstra: [58, 840, 792]
#     cost_dijkstra: 342.0
#     path_astar: [58, 840, 792]
#     cost_astar: 342.0
# ic| s: 143
#     d: 325
#     path_dijkstra: [143, 76, 325]
#     cost_dijkstra: 668.0
#     path_astar: [143, 76, 325]
#     cost_astar: 668.0
# ic| s: 143
#     d: 325
#     path_dijkstra: [143, 76, 325]
#     cost_dijkstra: 668.0
#     path_astar: [143, 76, 325]
#     cost_astar: 668.0
# ic| s: 763
#     d: 994
#     path_dijkstra: [763, 660, 807, 994]
#     cost_dijkstra: 746.0
#     path_astar: [763, 660, 807, 994]
#     cost_astar: 746.0
# ic| s: 763
#     d: 994
#     path_dijkstra: [763, 660, 807, 994]
#     cost_dijkstra: 746.0
#     path_astar: [763, 660, 807, 994]
#     cost_astar: 746.0
# ic| s: 516
#     d: 713
#     path_dijkstra: [516, 487, 713]
#     cost_dijkstra: 946.0
#     path_astar: [516, 487, 713]
#     cost_astar: 946.0
# ic| s: 516
#     d: 713
#     path_dijkstra: [516, 487, 713]
#     cost_dijkstra: 946.0
#     path_astar: [516, 487, 713]
#     cost_astar: 946.0
# ic| s: 318
#     d: 487
#     path_dijkstra: [318, 517, 923, 487]
#     cost_dijkstra: 451.0
#     path_astar: [318, 517, 923, 487]
#     cost_astar: 451.0
# ic| s: 318
#     d: 487
#     path_dijkstra: [318, 517, 923, 487]
#     cost_dijkstra: 451.0
#     path_astar: [318, 517, 923, 487]
#     cost_astar: 451.0
# ic| s: 116
#     d: 526
#     path_dijkstra: [116, 752, 980, 606, 526]
#     cost_dijkstra: 885.0
#     path_astar: [116, 752, 980, 606, 526]
#     cost_astar: 885.0
# ic| s: 116
#     d: 526
#     path_dijkstra: [116, 752, 980, 606, 526]
#     cost_dijkstra: 885.0
#     path_astar: [116, 752, 980, 606, 526]
#     cost_astar: 885.0
# ic| s: 396
#     d: 537
#     path_dijkstra: [396, 72, 33, 537]
#     cost_dijkstra: 680.0
#     path_astar: [396, 72, 33, 537]
#     cost_astar: 680.0
# ic| s: 396
#     d: 537
#     path_dijkstra: [396, 72, 33, 537]
#     cost_dijkstra: 680.0
#     path_astar: [396, 72, 33, 537]
#     cost_astar: 680.0
# ic| s: 260
#     d: 502
#     path_dijkstra: [260, 137, 502]
#     cost_dijkstra: 325.0
#     path_astar: [260, 137, 502]
#     cost_astar: 325.0
# ic| s: 622
#     d: 740
#     path_dijkstra: [622, 727, 740]
#     cost_dijkstra: 330.0
#     path_astar: [622, 727, 740]
#     cost_astar: 330.0
# ic| s: 260
#     d: 502
#     path_dijkstra: [260, 137, 502]
#     cost_dijkstra: 325.0
#     path_astar: [260, 137, 502]
#     cost_astar: 325.0
# ic| s: 622
#     d: 740
#     path_dijkstra: [622, 727, 740]
#     cost_dijkstra: 330.0
#     path_astar: [622, 727, 740]
#     cost_astar: 330.0
# ic| s: 10
#     d: 980
#     path_dijkstra: [10, 753, 888, 980]
#     cost_dijkstra: 338.0
#     path_astar: [10, 753, 888, 980]
#     cost_astar: 338.0
# ic| s: 20
#     d: 77
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [10, 753, 888, 980]
#     cost_astar: 338.0
# ic| s: 1
#     d: 49
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [10, 753, 888, 980]
#     cost_astar: 338.0
# ic| s: 41
#     d: 57
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [10, 753, 888, 980]
#     cost_astar: 338.0
# ic| s: 12
#     d: 90
#     path_dijkstra: [12, 41, 36, 0, 26, 9, 52, 58, 90]
#     cost_dijkstra: 284.0
#     path_astar: [12, 41, 36, 0, 26, 9, 52, 58, 90]
#     cost_astar: 284.0
# ic| s: 2
#     d: 95
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [12, 41, 36, 0, 26, 9, 52, 58, 90]
#     cost_astar: 284.0
# ic| s: 14
#     d: 32
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [12, 41, 36, 0, 26, 9, 52, 58, 90]
#     cost_astar: 284.0
# ic| s: 48
#     d: 75
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [12, 41, 36, 0, 26, 9, 52, 58, 90]
#     cost_astar: 284.0
# ic| s: 59
#     d: 77
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [12, 41, 36, 0, 26, 9, 52, 58, 90]
#     cost_astar: 284.0
# ic| s: 45
#     d: 76
#     path_dijkstra: None
# ...
#     d: 9
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [34, 877]
#     cost_astar: 349.0
# ic| s: 3
#     d: 10
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [34, 877]
#     cost_astar: 349.0
# ic| s: 11
#     d: 12
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [34, 877]
#     cost_astar: 349.0
# ic| s: 4
#     d: 6
#     path_dijkstra: [4, 6]
#     cost_dijkstra: 636.0
#     path_astar: [4, 6]
#     cost_astar: 636.0
# ic| s: 0
#     d: 9
#     path_dijkstra: [0, 9]
#     cost_dijkstra: 200.0
#     path_astar: [0, 9]
#     cost_astar: 200.0
# ic| s: 5
#     d: 8
#     path_dijkstra: [5, 8]
#     cost_dijkstra: 882.0
#     path_astar: [5, 8]
#     cost_astar: 882.0
# ic| s: 5
#     d: 6
#     path_dijkstra: [5, 6]
#     cost_dijkstra: 292.0
#     path_astar: [5, 6]
#     cost_astar: 292.0
# ic| s: 0
#     d: 7
#     path_dijkstra: [0, 7]
#     cost_dijkstra: 392.0
#     path_astar: [0, 7]
#     cost_astar: 392.0
# ic| s: 2
#     d: 6
#     path_dijkstra: [2, 6]
#     cost_dijkstra: 571.0
#     path_astar: [2, 6]
#     cost_astar: 571.0
# ic| s: 0
#     d: 3
#     path_dijkstra: [0, 3]
#     cost_dijkstra: 347.0
#     path_astar: [0, 3]
#     cost_astar: 347.0
# ic| s: 3
#     d: 6
#     path_dijkstra: [3, 6]
#     cost_dijkstra: 123.0
#     path_astar: [3, 6]
#     cost_astar: 123.0
# ic| s: 0
#     d: 5
#     path_dijkstra: [0, 5]
#     cost_dijkstra: 633.0
#     path_astar: [0, 5]
#     cost_astar: 633.0
# ic| s: 3
#     d: 4
#     path_dijkstra: [3, 4]
#     cost_dijkstra: 717.0
#     path_astar: [3, 4]
#     cost_astar: 717.0
# ic| s: 1
#     d: 2
#     path_dijkstra: [1, 2]
#     cost_dijkstra: 813.0
#     path_astar: [1, 2]
#     cost_astar: 813.0
# ic| s: 7
#     d: 9
#     path_dijkstra: [7, 9]
#     cost_dijkstra: 558.0
#     path_astar: [7, 9]
#     cost_astar: 558.0
# ic| s: 2
#     d: 7
#     path_dijkstra: [2, 7]
#     cost_dijkstra: 826.0
#     path_astar: [2, 7]
#     cost_astar: 826.0
# ic| s: 0
#     d: 8
#     path_dijkstra: [0, 8]
#     cost_dijkstra: 435.0
#     path_astar: [0, 8]
#     cost_astar: 435.0
# ic| s: 2
#     d: 5
#     path_dijkstra: [2, 5]
#     cost_dijkstra: 281.0
#     path_astar: [2, 5]
#     cost_astar: 281.0
# ic| s: 2
#     d: 4
#     path_dijkstra: [2, 4]
#     cost_dijkstra: 526.0
#     path_astar: [2, 4]
#     cost_astar: 526.0
# ic| s: 3
#     d: 5
#     path_dijkstra: [3, 5]
#     cost_dijkstra: 415.0
#     path_astar: [3, 5]
#     cost_astar: 415.0
# ic| s: 1
#     d: 5
#     path_dijkstra: [1, 5]
#     cost_dijkstra: 539.0
#     path_astar: [1, 5]
#     cost_astar: 539.0
# ic| s: 5
#     d: 9
#     path_dijkstra: [5, 9]
#     cost_dijkstra: 544.0
#     path_astar: [5, 9]
#     cost_astar: 544.0
# ic| s: 3
#     d: 9
#     path_dijkstra: [3, 9]
#     cost_dijkstra: 168.0
#     path_astar: [3, 9]
#     cost_astar: 168.0
# ic| s: 69
#     d: 92
#     path_dijkstra: [69, 21, 40, 92]
#     cost_dijkstra: 748.0
#     path_astar: [69, 21, 40, 92]
#     cost_astar: 748.0
# ic| s: 20
#     d: 63
#     path_dijkstra: [20, 63]
#     cost_dijkstra: 743.0
#     path_astar: [20, 63]
#     cost_astar: 743.0
# ic| s: 74
#     d: 86
#     path_dijkstra: [74, 46, 86]
#     cost_dijkstra: 1032.0
#     path_astar: [74, 46, 86]
#     cost_astar: 1032.0
# ic| s: 6
#     d: 97
#     path_dijkstra: [6, 97]
#     cost_dijkstra: 910.0
#     path_astar: [6, 97]
#     cost_astar: 910.0
# ic| s: 25
#     d: 36
#     path_dijkstra: [25, 36]
#     cost_dijkstra: 782.0
#     path_astar: [25, 36]
#     cost_astar: 782.0
# ic| s: 36
#     d: 92
#     path_dijkstra: [36, 92]
#     cost_dijkstra: 693.0
#     path_astar: [36, 92]
#     cost_astar: 693.0
# ic| s: 28
#     d: 56
#     path_dijkstra: [28, 56]
#     cost_dijkstra: 462.0
#     path_astar: [28, 56]
#     cost_astar: 462.0
# ic| s: 73
#     d: 98
#     path_dijkstra: [73, 20, 98]
#     cost_dijkstra: 529.0
#     path_astar: [73, 20, 98]
#     cost_astar: 529.0
# ic| s: 65
#     d: 87
#     path_dijkstra: [65, 44, 35, 87]
#     cost_dijkstra: 1036.0
#     path_astar: [65, 44, 35, 87]
#     cost_astar: 1036.0
# ic| s: 9
#     d: 91
#     path_dijkstra: [9, 0, 91]
#     cost_dijkstra: 513.0
#     path_astar: [9, 0, 91]
#     cost_astar: 513.0
# ic| s: 50
#     d: 76
#     path_dijkstra: [50, 78, 76]
#     cost_dijkstra: 898.0
#     path_astar: [50, 78, 76]
#     cost_astar: 898.0
# ic| s: 26
#     d: 48
#     path_dijkstra: [26, 30, 17, 48]
#     cost_dijkstra: 846.0
#     path_astar: [26, 30, 17, 48]
#     cost_astar: 846.0
# ic| s: 9
#     d: 37
#     path_dijkstra: [9, 32, 18, 37]
#     cost_dijkstra: 1013.0
#     path_astar: [9, 32, 18, 37]
#     cost_astar: 1013.0
# ic| s: 3
#     d: 84
#     path_dijkstra: [3, 88, 84]
#     cost_dijkstra: 619.0
#     path_astar: [3, 88, 84]
#     cost_astar: 619.0
# ic| s: 28
#     d: 57
#     path_dijkstra: [28, 57]
#     cost_dijkstra: 479.0
#     path_astar: [28, 57]
#     cost_astar: 479.0
# ic| s: 1
#     d: 4
#     path_dijkstra: [1, 9, 4]
#     cost_dijkstra: 935.0
#     path_astar: [1, 9, 4]
#     cost_astar: 935.0
# ic| s: 1
#     d: 22
#     path_dijkstra: [1, 22]
#     cost_dijkstra: 275.0
#     path_astar: [1, 22]
#     cost_astar: 275.0
# ic| s: 7
#     d: 87
#     path_dijkstra: [7, 87]
#     cost_dijkstra: 358.0
#     path_astar: [7, 87]
#     cost_astar: 358.0
# ic| s: 43
#     d: 77
#     path_dijkstra: [43, 77]
#     cost_dijkstra: 688.0
#     path_astar: [43, 77]
#     cost_astar: 688.0
# ic| s: 9
#     d: 97
#     path_dijkstra: [9, 0, 70, 97]
#     cost_dijkstra: 1020.0
#     path_astar: [9, 0, 70, 97]
#     cost_astar: 1020.0
# ic| s: 0
#     d: 3
#     path_dijkstra: [0, 7, 8, 3]
#     cost_dijkstra: 751.0
#     path_astar: [0, 7, 8, 3]
#     cost_astar: 751.0
# ic| s: 1
#     d: 5
#     path_dijkstra: [1, 5]
#     cost_dijkstra: 42.0
#     path_astar: [1, 5]
#     cost_astar: 42.0
# ic| s: 1
#     d: 8
#     path_dijkstra: [1, 0, 7, 8]
#     cost_dijkstra: -87.0
#     path_astar: [1, 0, 7, 8]
#     cost_astar: -87.0
# ic| s: 5
#     d: 8
#     path_dijkstra: [5, 4, 0, 7, 8]
#     cost_dijkstra: -8.0
#     path_astar: [5, 4, 0, 7, 8]
#     cost_astar: -8.0
# ic| s: 3
#     d: 6
#     path_dijkstra: [3, 2, 9, 6]
#     cost_dijkstra: 2065.0
#     path_astar: [3, 4, 0, 7, 8, 6]
#     cost_astar: 1892.0
# ic| s: 1
#     d: 3
#     path_dijkstra: [1, 5, 4, 3]
#     cost_dijkstra: 1011.0
#     path_astar: [1, 5, 4, 3]
#     cost_astar: 1011.0
# ic| s: 0
#     d: 8
#     path_dijkstra: [0, 7, 8]
#     cost_dijkstra: -751.0
#     path_astar: [0, 7, 8]
#     cost_astar: -751.0
# ic| s: 3
#     d: 8
#     path_dijkstra: [3, 4, 0, 7, 8]
#     cost_dijkstra: 1209.0
#     path_astar: [3, 4, 0, 7, 8]
#     cost_astar: 1209.0
# ic| s: 6
#     d: 7
#     path_dijkstra: [6, 7]
#     cost_dijkstra: 567.0
#     path_astar: [6, 7]
#     cost_astar: 567.0
# ic| s: 7
#     d: 8
#     path_dijkstra: [7, 8]
#     cost_dijkstra: -414.0
#     path_astar: [7, 8]
#     cost_astar: -414.0
# ic| s: 5
#     d: 7
#     path_dijkstra: [5, 4, 0, 7]
#     cost_dijkstra: 406.0
#     path_astar: [5, 4, 0, 7]
#     cost_astar: 406.0
# ic| s: 0
#     d: 7
#     path_dijkstra: [0, 7]
#     cost_dijkstra: -337.0
#     path_astar: [0, 7]
#     cost_astar: -337.0
# ic| s: 3
#     d: 7
#     path_dijkstra: [3, 4, 0, 7]
#     cost_dijkstra: 1623.0
#     path_astar: [3, 4, 0, 7]
#     cost_astar: 1623.0
# ic| s: 3
#     d: 4
#     path_dijkstra: [3, 4]
#     cost_dijkstra: 1045.0
#     path_astar: [3, 4]
#     cost_astar: 1045.0
# ic| s: 3
#     d: 5
#     path_dijkstra: [3, 4, 0, 7, 5]
#     cost_dijkstra: 2535.0
#     path_astar: [3, 4, 0, 7, 5]
#     cost_astar: 2535.0
# ic| s: 2
#     d: 3
#     path_dijkstra: [2, 9, 7, 8, 3]
#     cost_dijkstra: 2231.0
#     path_astar: [2, 9, 7, 8, 3]
#     cost_astar: 2231.0
# ic| s: 6
#     d: 8
#     path_dijkstra: [6, 7, 8]
#     cost_dijkstra: 153.0
#     path_astar: [6, 7, 8]
#     cost_astar: 153.0
# ic| s: 1
#     d: 2
#     path_dijkstra: [1, 9, 2]
#     cost_dijkstra: 844.0
#     path_astar: [1, 9, 2]
#     cost_astar: 844.0
# ic| s: 3
#     d: 9
#     path_dijkstra: [3, 2, 9]
#     cost_dijkstra: 1386.0
#     path_astar: [3, 2, 9]
#     cost_astar: 1386.0
# ic| s: 0
#     d: 9
#     path_dijkstra: [0, 7, 2, 9]
#     cost_dijkstra: 637.0
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 26
#     d: 48
#     path_dijkstra: [26, 30, 17, 48]
#     cost_dijkstra: 846.0
#     path_astar: [26, 30, 17, 48]
#     cost_astar: 846.0
# ic| s: 9
#     d: 37
#     path_dijkstra: [9, 32, 18, 37]
#     cost_dijkstra: 1013.0
#     path_astar: [9, 32, 18, 37]
#     cost_astar: 1013.0
# ic| s: 3
#     d: 84
#     path_dijkstra: [3, 88, 84]
#     cost_dijkstra: 619.0
#     path_astar: [3, 88, 84]
#     cost_astar: 619.0
# ic| s: 28
#     d: 57
#     path_dijkstra: [28, 57]
#     cost_dijkstra: 479.0
#     path_astar: [28, 57]
#     cost_astar: 479.0
# ic| s: 1
#     d: 4
#     path_dijkstra: [1, 9, 4]
#     cost_dijkstra: 935.0
#     path_astar: [1, 9, 4]
#     cost_astar: 935.0
# ic| s: 1
#     d: 22
#     path_dijkstra: [1, 22]
#     cost_dijkstra: 275.0
#     path_astar: [1, 22]
#     cost_astar: 275.0
# ic| s: 7
#     d: 87
#     path_dijkstra: [7, 87]
#     cost_dijkstra: 358.0
#     path_astar: [7, 87]
#     cost_astar: 358.0
# ic| s: 43
#     d: 77
#     path_dijkstra: [43, 77]
#     cost_dijkstra: 688.0
#     path_astar: [43, 77]
#     cost_astar: 688.0
# ic| s: 9
#     d: 97
#     path_dijkstra: [9, 0, 70, 97]
#     cost_dijkstra: 1020.0
#     path_astar: [9, 0, 70, 97]
#     cost_astar: 1020.0
# ic| s: 0
#     d: 3
#     path_dijkstra: [0, 7, 8, 3]
#     cost_dijkstra: 751.0
#     path_astar: [0, 7, 8, 3]
#     cost_astar: 751.0
# ic| s: 1
#     d: 5
#     path_dijkstra: [1, 5]
#     cost_dijkstra: 42.0
#     path_astar: [1, 5]
#     cost_astar: 42.0
# ic| s: 1
#     d: 8
#     path_dijkstra: [1, 0, 7, 8]
#     cost_dijkstra: -87.0
#     path_astar: [1, 0, 7, 8]
#     cost_astar: -87.0
# ic| s: 5
#     d: 8
#     path_dijkstra: [5, 4, 0, 7, 8]
#     cost_dijkstra: -8.0
#     path_astar: [5, 4, 0, 7, 8]
#     cost_astar: -8.0
# ic| s: 3
#     d: 6
#     path_dijkstra: [3, 2, 9, 6]
#     cost_dijkstra: 2065.0
#     path_astar: [3, 4, 0, 7, 8, 6]
#     cost_astar: 1892.0
# ic| s: 1
#     d: 3
#     path_dijkstra: [1, 5, 4, 3]
#     cost_dijkstra: 1011.0
#     path_astar: [1, 5, 4, 3]
#     cost_astar: 1011.0
# ic| s: 0
#     d: 8
#     path_dijkstra: [0, 7, 8]
#     cost_dijkstra: -751.0
#     path_astar: [0, 7, 8]
#     cost_astar: -751.0
# ic| s: 3
#     d: 8
#     path_dijkstra: [3, 4, 0, 7, 8]
#     cost_dijkstra: 1209.0
#     path_astar: [3, 4, 0, 7, 8]
#     cost_astar: 1209.0
# ic| s: 6
#     d: 7
#     path_dijkstra: [6, 7]
#     cost_dijkstra: 567.0
#     path_astar: [6, 7]
#     cost_astar: 567.0
# ic| s: 7
#     d: 8
#     path_dijkstra: [7, 8]
#     cost_dijkstra: -414.0
#     path_astar: [7, 8]
#     cost_astar: -414.0
# ic| s: 5
#     d: 7
#     path_dijkstra: [5, 4, 0, 7]
#     cost_dijkstra: 406.0
#     path_astar: [5, 4, 0, 7]
#     cost_astar: 406.0
# ic| s: 0
#     d: 7
#     path_dijkstra: [0, 7]
#     cost_dijkstra: -337.0
#     path_astar: [0, 7]
#     cost_astar: -337.0
# ic| s: 3
#     d: 7
#     path_dijkstra: [3, 4, 0, 7]
#     cost_dijkstra: 1623.0
#     path_astar: [3, 4, 0, 7]
#     cost_astar: 1623.0
# ic| s: 3
#     d: 4
#     path_dijkstra: [3, 4]
#     cost_dijkstra: 1045.0
#     path_astar: [3, 4]
#     cost_astar: 1045.0
# ic| s: 3
#     d: 5
#     path_dijkstra: [3, 4, 0, 7, 5]
#     cost_dijkstra: 2535.0
#     path_astar: [3, 4, 0, 7, 5]
#     cost_astar: 2535.0
# ic| s: 2
#     d: 3
#     path_dijkstra: [2, 9, 7, 8, 3]
#     cost_dijkstra: 2231.0
#     path_astar: [2, 9, 7, 8, 3]
#     cost_astar: 2231.0
# ic| s: 6
#     d: 8
#     path_dijkstra: [6, 7, 8]
#     cost_dijkstra: 153.0
#     path_astar: [6, 7, 8]
#     cost_astar: 153.0
# ic| s: 1
#     d: 2
#     path_dijkstra: [1, 9, 2]
#     cost_dijkstra: 844.0
#     path_astar: [1, 9, 2]
#     cost_astar: 844.0
# ic| s: 3
#     d: 9
#     path_dijkstra: [3, 2, 9]
#     cost_dijkstra: 1386.0
#     path_astar: [3, 2, 9]
#     cost_astar: 1386.0
# ic| s: 0
#     d: 9
#     path_dijkstra: [0, 7, 2, 9]
#     cost_dijkstra: 637.0
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 496
#     d: 842
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 293
#     d: 455
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 181
#     d: 520
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 53
#     d: 981
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 115
#     d: 635
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 438
#     d: 442
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 183
#     d: 437
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 21
#     d: 25
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 14
#     d: 413
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 5
#     d: 529
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 582
#     d: 777
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 830
#     d: 978
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 169
#     d: 488
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 512
#     d: 727
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 388
#     d: 629
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 185
#     d: 294
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 273
#     d: 523
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 232
#     d: 398
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 180
#     d: 720
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 237
#     d: 398
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 496
#     d: 842
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 293
#     d: 455
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 181
#     d: 520
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 53
#     d: 981
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 115
#     d: 635
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 438
#     d: 442
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 183
#     d: 437
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 21
#     d: 25
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 14
#     d: 413
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 5
#     d: 529
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 582
#     d: 777
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 830
#     d: 978
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 169
#     d: 488
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 512
#     d: 727
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 388
#     d: 629
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 185
#     d: 294
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 273
#     d: 523
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 232
#     d: 398
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 180
#     d: 720
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
# ic| s: 237
#     d: 398
#     path_dijkstra: None
#     cost_dijkstra: inf
#     path_astar: [0, 7, 2, 9]
#     cost_astar: 637.0
